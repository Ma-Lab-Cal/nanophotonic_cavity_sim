# %% [markdown]
# # BandStructureSim — Tutorial Notebook
#
# A hands-on guide to computing photonic-crystal slab band structures with the
# `BandStructureSim` class, which wraps MIT's [MPB](https://mpb.readthedocs.io/) solver.
#
# All physical dimensions are in **µm**. Frequencies are returned in normalised
# units (c/a) and can be converted to THz or Hz.

# %% [markdown]
# ## 0 — Imports
#
# Place `bandstructure_class.py` in the same directory as this notebook (or on your Python path).

# %%
from bandstructure_class import BandStructureSim
import numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
C0 = td.constants.C_0

# %matplotlib inline

# %% [markdown]
# ## 1 — Creating a Simulation Object
#
# `BandStructureSim` models a **1-D periodic dielectric slab** with air holes.
#
# ### Constructor parameters
#
# | Parameter | Description |
# |---|---|
# | `Lx` | Lattice constant along x (µm). Used as the normalisation unit *a*. |
# | `Ly` | Width of the nanobeam / slab in y (µm). |
# | `thickness` | Slab thickness in z (µm). |
# | `geometry` | Hole shape: `"circular"`, `"ellipse"`, or `"square"`. |
# | `hole_params` | Hole dimensions in µm — `[diameter]` for circular, `[sx, sy]` for ellipse/square. |
# | `material_index` | Refractive index of the slab material. |
# | `factor_y`, `factor_z` | Supercell padding multipliers (default 5 and 10). |
# | `num_bands` | Number of frequency bands to compute. |
# | `resolution` | Grid points per unit cell. Higher = more accurate but slower. |

# %% [markdown]
# ### 1.1 — Circular holes

# %%
thickness = 0.25
wl0 = 1.324
freq0 = C0 / wl0


Lx = 0.6
Ly = 0.7
dx = 0.35
dy = 0.35

sim = BandStructureSim(
    Lx=Lx, Ly=Ly, thickness=thickness,
    geometry="ellipse", geometry_params=[dx, dy],
    material_index=2.0, num_bands=3, resolution=16,
)

sim.init_solver()
sim.plot_epsilon(periods=3)
#sim.run_bandstructure(k_min=0, k_max=0.5, n_k=8)
#sim.plot_bands(units='THz', freq0_Hz=freq0)
# Out:
# Working in 3 dimensions.
# Grid size is 16 x 96 x 70.
# Solving for 3 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 5.83333, 0)
#      (0, 0, 4.16667)
# Cell volume = 24.3056
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.171429, -0)
#      (0, -0, 0.24)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.16667,0.416667)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.583333,0.583333,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# epsilon: 1-4, mean 1.04626, harm. mean 1.01226, 1.82199% > 1, 1.54191% "fill"
# real part range: 1 .. 4
# (<Figure size 1800x500 with 3 Axes>,
#  array([<Axes: title={'center': 'XY cross-section (z = 0)'}>,
#         <Axes: title={'center': 'YZ cross-section (x = 0)'}>,
#         <Axes: title={'center': 'XZ cross-section (y = 0)'}>], dtype=object))

# %%
from bandstructure_class import BandStructureSim
import numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
C0 = td.constants.C_0

# %matplotlib inline

sim = BandStructureSim(
    Lx=1, Ly=0.2, thickness=0.22,
    geometry='sawtooth_square',
    geometry_params=[0.2, 0.3, 0.2],
    material_index=3.48,
)

sim.init_solver()
sim.plot_epsilon(periods=3)

sim = BandStructureSim(
    Lx=1, Ly=0.2, thickness=0.22,
    geometry='sawtooth_round',
    geometry_params=[0.2, 0.3, 0.2],
    material_index=3.48,
)

sim.init_solver()
sim.plot_epsilon(periods=3)
# Out:
# Working in 3 dimensions.
# Grid size is 32 x 128 x 72.
# Solving for 5 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 2.2)
# Cell volume = 8.8
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.454545)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,0.2,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0.25,0)
#           size (0.2,0.3,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-0.25,0)
#           size (0.2,0.3,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 5 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# epsilon: 1-12.1104, mean 1.08869, harm. mean 1.00903, 1.0966% > 1, 0.798282% "fill"
# real part range: 1 .. 12.1104
# Working in 3 dimensions.
# Grid size is 32 x 128 x 72.
# Solving for 5 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 4, 0)
#      (0, 0, 2.2)
# Cell volume = 8.8
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.25, -0)
#      (0, -0, 0.454545)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,0.2,0.22)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 0.22, axis (0,0,1), sidewall angle: 0 radians, 258 vertices:
#           (-0.5,0.1,-0.11)
#           (-0.2,0.1,-0.11)
#           (-0.194935,0.100128,-0.11)
#           (-0.189883,0.100513,-0.11)
#           (-0.184857,0.101153,-0.11)
#           (-0.17987,0.102047,-0.11)
#           (-0.174935,0.103192,-0.11)
#           (-0.170064,0.104586,-0.11)
#           (-0.165269,0.106225,-0.11)
#           (-0.160564,0.108104,-0.11)
#           (-0.155961,0.11022,-0.11)
#           (-0.15147,0.112565,-0.11)
#           (-0.147104,0.115136,-0.11)
#           (-0.142873,0.117924,-0.11)
#           (-0.138789,0.120922,-0.11)
#           (-0.134863,0.124124,-0.11)
#           (-0.131103,0.127521,-0.11)
#           (-0.127521,0.131103,-0.11)
#           (-0.124124,0.134863,-0.11)
#           (-0.120922,0.138789,-0.11)
#           (-0.117924,0.142873,-0.11)
#           (-0.115136,0.147104,-0.11)
#           (-0.112565,0.15147,-0.11)
#           (-0.11022,0.155961,-0.11)
#           (-0.108104,0.160564,-0.11)
#           (-0.106225,0.165269,-0.11)
#           (-0.104586,0.170064,-0.11)
#           (-0.103192,0.174935,-0.11)
#           (-0.102047,0.17987,-0.11)
#           (-0.101153,0.184857,-0.11)
#           (-0.100513,0.189883,-0.11)
#           (-0.100128,0.194935,-0.11)
#           (-0.1,0.2,-0.11)
#           (-0.1,0.3,-0.11)
#           (-0.0998717,0.305065,-0.11)
#           (-0.0994869,0.310117,-0.11)
#           (-0.0988468,0.315143,-0.11)
#           (-0.097953,0.32013,-0.11)
#           (-0.0968077,0.325065,-0.11)
#           (-0.0954139,0.329936,-0.11)
#           (-0.0937752,0.334731,-0.11)
#           (-0.0918958,0.339436,-0.11)
#           (-0.0897805,0.344039,-0.11)
#           (-0.0874347,0.34853,-0.11)
#           (-0.0848644,0.352896,-0.11)
#           (-0.0820763,0.357127,-0.11)
#           (-0.0790776,0.361211,-0.11)
#           (-0.0758758,0.365137,-0.11)
#           (-0.0724793,0.368897,-0.11)
#           (-0.0688967,0.372479,-0.11)
#           (-0.0651372,0.375876,-0.11)
#           (-0.0612106,0.379078,-0.11)
#           (-0.0571268,0.382076,-0.11)
#           (-0.0528964,0.384864,-0.11)
#           (-0.0485302,0.387435,-0.11)
#           (-0.0440394,0.38978,-0.11)
#           (-0.0394356,0.391896,-0.11)
#           (-0.0347305,0.393775,-0.11)
#           (-0.0299363,0.395414,-0.11)
#           (-0.0250653,0.396808,-0.11)
#           (-0.0201299,0.397953,-0.11)
#           (-0.0151428,0.398847,-0.11)
#           (-0.0101168,0.399487,-0.11)
#           (-0.00506492,0.399872,-0.11)
#           (1.25615e-17,0.4,-0.11)
#           (0.00506492,0.399872,-0.11)
#           (0.0101168,0.399487,-0.11)
#           (0.0151428,0.398847,-0.11)
#           (0.0201299,0.397953,-0.11)
#           (0.0250653,0.396808,-0.11)
#           (0.0299363,0.395414,-0.11)
#           (0.0347305,0.393775,-0.11)
#           (0.0394356,0.391896,-0.11)
#           (0.0440394,0.38978,-0.11)
#           (0.0485302,0.387435,-0.11)
#           (0.0528964,0.384864,-0.11)
#           (0.0571268,0.382076,-0.11)
#           (0.0612106,0.379078,-0.11)
#           (0.0651372,0.375876,-0.11)
#           (0.0688967,0.372479,-0.11)
#           (0.0724793,0.368897,-0.11)
#           (0.0758758,0.365137,-0.11)
#           (0.0790776,0.361211,-0.11)
#           (0.0820763,0.357127,-0.11)
#           (0.0848644,0.352896,-0.11)
#           (0.0874347,0.34853,-0.11)
#           (0.0897805,0.344039,-0.11)
#           (0.0918958,0.339436,-0.11)
#           (0.0937752,0.334731,-0.11)
#           (0.0954139,0.329936,-0.11)
#           (0.0968077,0.325065,-0.11)
#           (0.097953,0.32013,-0.11)
#           (0.0988468,0.315143,-0.11)
#           (0.0994869,0.310117,-0.11)
#           (0.0998717,0.305065,-0.11)
#           (0.1,0.3,-0.11)
#           (0.1,0.2,-0.11)
#           (0.100128,0.194935,-0.11)
#           (0.100513,0.189883,-0.11)
#           (0.101153,0.184857,-0.11)
#           (0.102047,0.17987,-0.11)
#           (0.103192,0.174935,-0.11)
#           (0.104586,0.170064,-0.11)
#           (0.106225,0.165269,-0.11)
#           (0.108104,0.160564,-0.11)
#           (0.11022,0.155961,-0.11)
#           (0.112565,0.15147,-0.11)
#           (0.115136,0.147104,-0.11)
#           (0.117924,0.142873,-0.11)
#           (0.120922,0.138789,-0.11)
#           (0.124124,0.134863,-0.11)
#           (0.127521,0.131103,-0.11)
#           (0.131103,0.127521,-0.11)
#           (0.134863,0.124124,-0.11)
#           (0.138789,0.120922,-0.11)
#           (0.142873,0.117924,-0.11)
#           (0.147104,0.115136,-0.11)
#           (0.15147,0.112565,-0.11)
#           (0.155961,0.11022,-0.11)
#           (0.160564,0.108104,-0.11)
#           (0.165269,0.106225,-0.11)
#           (0.170064,0.104586,-0.11)
#           (0.174935,0.103192,-0.11)
#           (0.17987,0.102047,-0.11)
#           (0.184857,0.101153,-0.11)
#           (0.189883,0.100513,-0.11)
#           (0.194935,0.100128,-0.11)
#           (0.2,0.1,-0.11)
#           (0.5,0.1,-0.11)
#           (0.5,-0.1,-0.11)
#           (0.2,-0.1,-0.11)
#           (0.194935,-0.100128,-0.11)
#           (0.189883,-0.100513,-0.11)
#           (0.184857,-0.101153,-0.11)
#           (0.17987,-0.102047,-0.11)
#           (0.174935,-0.103192,-0.11)
#           (0.170064,-0.104586,-0.11)
#           (0.165269,-0.106225,-0.11)
#           (0.160564,-0.108104,-0.11)
#           (0.155961,-0.11022,-0.11)
#           (0.15147,-0.112565,-0.11)
#           (0.147104,-0.115136,-0.11)
#           (0.142873,-0.117924,-0.11)
#           (0.138789,-0.120922,-0.11)
#           (0.134863,-0.124124,-0.11)
#           (0.131103,-0.127521,-0.11)
#           (0.127521,-0.131103,-0.11)
#           (0.124124,-0.134863,-0.11)
#           (0.120922,-0.138789,-0.11)
#           (0.117924,-0.142873,-0.11)
#           (0.115136,-0.147104,-0.11)
#           (0.112565,-0.15147,-0.11)
#           (0.11022,-0.155961,-0.11)
#           (0.108104,-0.160564,-0.11)
#           (0.106225,-0.165269,-0.11)
#           (0.104586,-0.170064,-0.11)
#           (0.103192,-0.174935,-0.11)
#           (0.102047,-0.17987,-0.11)
#           (0.101153,-0.184857,-0.11)
#           (0.100513,-0.189883,-0.11)
#           (0.100128,-0.194935,-0.11)
#           (0.1,-0.2,-0.11)
#           (0.1,-0.3,-0.11)
#           (0.0998717,-0.305065,-0.11)
#           (0.0994869,-0.310117,-0.11)
#           (0.0988468,-0.315143,-0.11)
#           (0.097953,-0.32013,-0.11)
#           (0.0968077,-0.325065,-0.11)
#           (0.0954139,-0.329936,-0.11)
#           (0.0937752,-0.334731,-0.11)
#           (0.0918958,-0.339436,-0.11)
#           (0.0897805,-0.344039,-0.11)
#           (0.0874347,-0.34853,-0.11)
#           (0.0848644,-0.352896,-0.11)
#           (0.0820763,-0.357127,-0.11)
#           (0.0790776,-0.361211,-0.11)
#           (0.0758758,-0.365137,-0.11)
#           (0.0724793,-0.368897,-0.11)
#           (0.0688967,-0.372479,-0.11)
#           (0.0651372,-0.375876,-0.11)
#           (0.0612106,-0.379078,-0.11)
#           (0.0571268,-0.382076,-0.11)
#           (0.0528964,-0.384864,-0.11)
#           (0.0485302,-0.387435,-0.11)
#           (0.0440394,-0.38978,-0.11)
#           (0.0394356,-0.391896,-0.11)
#           (0.0347305,-0.393775,-0.11)
#           (0.0299363,-0.395414,-0.11)
#           (0.0250653,-0.396808,-0.11)
#           (0.0201299,-0.397953,-0.11)
#           (0.0151428,-0.398847,-0.11)
#           (0.0101168,-0.399487,-0.11)
#           (0.00506492,-0.399872,-0.11)
#           (1.25615e-17,-0.4,-0.11)
#           (-0.00506492,-0.399872,-0.11)
#           (-0.0101168,-0.399487,-0.11)
#           (-0.0151428,-0.398847,-0.11)
#           (-0.0201299,-0.397953,-0.11)
#           (-0.0250653,-0.396808,-0.11)
#           (-0.0299363,-0.395414,-0.11)
#           (-0.0347305,-0.393775,-0.11)
#           (-0.0394356,-0.391896,-0.11)
#           (-0.0440394,-0.38978,-0.11)
#           (-0.0485302,-0.387435,-0.11)
#           (-0.0528964,-0.384864,-0.11)
#           (-0.0571268,-0.382076,-0.11)
#           (-0.0612106,-0.379078,-0.11)
#           (-0.0651372,-0.375876,-0.11)
#           (-0.0688967,-0.372479,-0.11)
#           (-0.0724793,-0.368897,-0.11)
#           (-0.0758758,-0.365137,-0.11)
#           (-0.0790776,-0.361211,-0.11)
#           (-0.0820763,-0.357127,-0.11)
#           (-0.0848644,-0.352896,-0.11)
#           (-0.0874347,-0.34853,-0.11)
#           (-0.0897805,-0.344039,-0.11)
#           (-0.0918958,-0.339436,-0.11)
#           (-0.0937752,-0.334731,-0.11)
#           (-0.0954139,-0.329936,-0.11)
#           (-0.0968077,-0.325065,-0.11)
#           (-0.097953,-0.32013,-0.11)
#           (-0.0988468,-0.315143,-0.11)
#           (-0.0994869,-0.310117,-0.11)
#           (-0.0998717,-0.305065,-0.11)
#           (-0.1,-0.3,-0.11)
#           (-0.1,-0.2,-0.11)
#           (-0.100128,-0.194935,-0.11)
#           (-0.100513,-0.189883,-0.11)
#           (-0.101153,-0.184857,-0.11)
#           (-0.102047,-0.17987,-0.11)
#           (-0.103192,-0.174935,-0.11)
#           (-0.104586,-0.170064,-0.11)
#           (-0.106225,-0.165269,-0.11)
#           (-0.108104,-0.160564,-0.11)
#           (-0.11022,-0.155961,-0.11)
#           (-0.112565,-0.15147,-0.11)
#           (-0.115136,-0.147104,-0.11)
#           (-0.117924,-0.142873,-0.11)
#           (-0.120922,-0.138789,-0.11)
#           (-0.124124,-0.134863,-0.11)
#           (-0.127521,-0.131103,-0.11)
#           (-0.131103,-0.127521,-0.11)
#           (-0.134863,-0.124124,-0.11)
#           (-0.138789,-0.120922,-0.11)
#           (-0.142873,-0.117924,-0.11)
#           (-0.147104,-0.115136,-0.11)
#           (-0.15147,-0.112565,-0.11)
#           (-0.155961,-0.11022,-0.11)
#           (-0.160564,-0.108104,-0.11)
#           (-0.165269,-0.106225,-0.11)
#           (-0.170064,-0.104586,-0.11)
#           (-0.174935,-0.103192,-0.11)
#           (-0.17987,-0.102047,-0.11)
#           (-0.184857,-0.101153,-0.11)
#           (-0.189883,-0.100513,-0.11)
#           (-0.194935,-0.100128,-0.11)
#           (-0.2,-0.1,-0.11)
#           (-0.5,-0.1,-0.11)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# epsilon: 1-12.1104, mean 1.08882, harm. mean 1.00901, 1.1183% > 1, 0.799436% "fill"
# real part range: 1 .. 12.1104
# (<Figure size 1800x500 with 3 Axes>,
#  array([<Axes: title={'center': 'XY cross-section (z = 0)'}>,
#         <Axes: title={'center': 'YZ cross-section (x = 0)'}>,
#         <Axes: title={'center': 'XZ cross-section (y = 0)'}>], dtype=object))

# %% [markdown]
# ## 2 — Computing a Band Structure
#
# Call `run_bandstructure()` to solve for both **TE-like (z-even)** and **TM-like (z-odd)** modes
# along a 1-D k-path from `k_min` to `k_max` (in units of 2π/a).

# %%
kpts, kpar, zeven_freqs, zodd_freqs = sim.run_bandstructure(
    k_min=0.0,  # start of k-path
    k_max=0.5,  # band edge (π/a)
    n_k=8,     # number of interpolated k-points
)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.531915,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 10 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10307002067565918
# solve_kpoint (0,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     iteration    1: trace = 0.793998839898276 (198.431% change)
#     iteration    2: trace = 0.05903211119493444 (172.319% change)
#     iteration    3: trace = 0.05127323297073547 (14.068% change)
#     iteration    4: trace = 0.04970921375614852 (3.09761% change)
#     iteration    5: trace = 0.0487952247716124 (1.85573% change)
#     iteration    6: trace = 0.04780831094068132 (2.04323% change)
#     iteration    7: trace = 0.04663385127891106 (2.48715% change)
#     iteration    8: trace = 0.04562792685337054 (2.18059% change)
#     iteration    9: trace = 0.04520631051453378 (0.92832% change)
#     iteration   10: trace = 0.04510013106663156 (0.235154% change)
#     iteration   11: trace = 0.04505431160518494 (0.101647% change)
#     iteration   12: trace = 0.04503919985841209 (0.0335468% change)
#     iteration   13: trace = 0.04503438662163518 (0.0106873% change)
#     iteration   14: trace = 0.04503312687886268 (0.00279733% change)
#     iteration   15: trace = 0.04503282193045453 (0.000677167% change)
#     iteration   16: trace = 0.04503269639601969 (0.000278762% change)
#     iteration   17: trace = 0.04503264595157343 (0.000112017% change)
#     iteration   18: trace = 0.04503263278270073 (2.9243e-05% change)
#     iteration   19: trace = 0.04503263029438614 (5.52558e-06% change)
# Finished solving for bands 2 to 4 after 19 iterations.
# zevenfreqs:, 1, 0, 0, 0, 0, 0, 0.0897281, 0.0932495, 0.168185
# elapsed time for k point: 3.080242872238159
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.05717284287169911 (2.99771% change)
#     iteration    2: trace = 0.05696329189922315 (0.367195% change)
#     iteration    3: trace = 0.0568933943126905 (0.122782% change)
#     iteration    4: trace = 0.05688904445584139 (0.00764592% change)
#     iteration    5: trace = 0.05688874825907714 (0.000520658% change)
#     iteration    6: trace = 0.05688871028212894 (6.67565e-05% change)
#     iteration    7: trace = 0.05688869871248483 (2.03373e-05% change)
#     iteration    8: trace = 0.05688869758858609 (1.97561e-06% change)
# Finished solving for bands 1 to 4 after 8 iterations.
# zevenfreqs:, 2, 0.0555556, 0, 0, 0.0555556, 0.0546307, 0.105346, 0.107531, 0.176758
# elapsed time for k point: 1.5905139446258545
# solve_kpoint (0.111111,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.09237610885328978 (1.02518% change)
#     iteration    2: trace = 0.09227373004809405 (0.11089% change)
#     iteration    3: trace = 0.09224035958251869 (0.0361712% change)
#     iteration    4: trace = 0.09223404548793612 (0.0068455% change)
#     iteration    5: trace = 0.09223297116182815 (0.00116479% change)
#     iteration    6: trace = 0.09223277732069095 (0.000210165% change)
#     iteration    7: trace = 0.09223269333111106 (9.10627e-05% change)
#     iteration    8: trace = 0.09223264630408118 (5.09874e-05% change)
#     iteration    9: trace = 0.09223263635629891 (1.07855e-05% change)
#     iteration   10: trace = 0.09223263606043725 (3.20778e-07% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 3, 0.111111, 0, 0, 0.111111, 0.108874, 0.141697, 0.142214, 0.20019
# elapsed time for k point: 1.9402461051940918
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.1503899714826837 (0.603808% change)
#     iteration    2: trace = 0.1502310746443817 (0.105712% change)
#     iteration    3: trace = 0.1502023501245149 (0.0191221% change)
#     iteration    4: trace = 0.1501953544701973 (0.0046576% change)
#     iteration    5: trace = 0.1501924746053394 (0.00191743% change)
#     iteration    6: trace = 0.1501911564701968 (0.000877634% change)
#     iteration    7: trace = 0.1501906364102573 (0.000346266% change)
#     iteration    8: trace = 0.1501904991889785 (9.13648e-05% change)
#     iteration    9: trace = 0.1501904497311681 (3.29301e-05% change)
#     iteration   10: trace = 0.1501904305036328 (1.28021e-05% change)
#     iteration   11: trace = 0.1501904198316442 (7.10564e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 4, 0.166667, 0, 0, 0.166667, 0.161749, 0.184409, 0.188102, 0.233749
# elapsed time for k point: 2.1253058910369873
# solve_kpoint (0.222222,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.229176005042812 (0.678373% change)
#     iteration    2: trace = 0.2287561344514934 (0.183377% change)
#     iteration    3: trace = 0.2286800000448212 (0.0332874% change)
#     iteration    4: trace = 0.2286543860685963 (0.0112014% change)
#     iteration    5: trace = 0.2286423241425206 (0.00527532% change)
#     iteration    6: trace = 0.2286379582499185 (0.0019095% change)
#     iteration    7: trace = 0.2286355397552406 (0.00105779% change)
#     iteration    8: trace = 0.2286341464634281 (0.000609396% change)
#     iteration    9: trace = 0.228633547816834 (0.000261836% change)
#     iteration   10: trace = 0.2286326802703884 (0.000379449% change)
#     near maximum in trace
#     iteration   11: trace = 0.2281628926912851 (0.205688% change)
#     iteration   12: trace = 0.228159055778188 (0.00168167% change)
#     iteration   13: trace = 0.2281550937644534 (0.00173653% change)
#     iteration   14: trace = 0.228151012842899 (0.00178868% change)
#     iteration   15: trace = 0.2281468137911726 (0.00184049% change)
#     iteration   16: trace = 0.2281424929314206 (0.00189391% change)
#     iteration   17: trace = 0.2281380429930904 (0.00195053% change)
#     iteration   18: trace = 0.2281334538081134 (0.0020116% change)
#     iteration   19: trace = 0.2281287128412166 (0.00207818% change)
#     iteration   20: trace = 0.2281238055902543 (0.00215111% change)
#     iteration   21: trace = 0.2281187159021825 (0.00223113% change)
#     iteration   22: trace = 0.2281134262522653 (0.00231884% change)
#     iteration   23: trace = 0.2281079180337932 (0.00241471% change)
#     iteration   24: trace = 0.2281021719055479 (0.00251907% change)
#     iteration   25: trace = 0.2280961682443561 (0.00263204% change)
#     iteration   26: trace = 0.2280898877487802 (0.00275348% change)
#     iteration   27: trace = 0.228083312233669 (0.0028829% change)
#     iteration   28: trace = 0.2280764256391863 (0.00301938% change)
#     iteration   29: trace = 0.2280692152463099 (0.00316144% change)
#     iteration   30: trace = 0.2280616730392673 (0.00330704% change)
#     iteration   31: trace = 0.2280537970850876 (0.00345349% change)
#     iteration   32: trace = 0.2280455927233672 (0.00359762% change)
#     iteration   33: trace = 0.2280370733024777 (0.00373591% change)
#     iteration   34: trace = 0.2280282601998102 (0.00386484% change)
#     iteration   35: trace = 0.2280191819561119 (0.00398127% change)
#     iteration   36: trace = 0.2280098725388074 (0.00408282% change)
#     iteration   37: trace = 0.2280003689774765 (0.00416814% change)
#     iteration   38: trace = 0.2279907087991958 (0.004237% change)
#     iteration   39: trace = 0.2279809277509468 (0.0042902% change)
#     iteration   40: trace = 0.2279710582058068 (0.0043292% change)
#     iteration   41: trace = 0.2279611284534286 (0.0043558% change)
#     iteration   42: trace = 0.2279511628555227 (0.00437172% change)
#     iteration   43: trace = 0.227941182674253 (0.00437831% change)
#     iteration   44: trace = 0.2279312072868036 (0.00437639% change)
#     iteration   45: trace = 0.2279212554776447 (0.00436624% change)
#     iteration   46: trace = 0.227911346530377 (0.00434763% change)
#     iteration   47: trace = 0.2279015009053519 (0.00432003% change)
#     iteration   48: trace = 0.2278917403771501 (0.00428288% change)
#     iteration   49: trace = 0.2278820876103821 (0.00423577% change)
#     iteration   50: trace = 0.2278725652607453 (0.00417872% change)
#     iteration   51: trace = 0.2278631947795387 (0.00411224% change)
#     iteration   52: trace = 0.2278539951499964 (0.00403743% change)
#     iteration   53: trace = 0.2278449817778372 (0.00395584% change)
#     iteration   54: trace = 0.2278361657000774 (0.00386941% change)
#     iteration   55: trace = 0.227827553187982 (0.00378021% change)
#     iteration   56: trace = 0.2278191457315662 (0.00369034% change)
#     iteration   57: trace = 0.227810940328624 (0.00360178% change)
#     iteration   58: trace = 0.22780292997048 (0.00351629% change)
#     iteration   59: trace = 0.2277951042162633 (0.00343538% change)
#     iteration   60: trace = 0.2277874497663616 (0.00336029% change)
#     iteration   61: trace = 0.22777995097221 (0.00329207% change)
#     iteration   62: trace = 0.2277725902450697 (0.00323156% change)
#     iteration   63: trace = 0.2277653483461142 (0.00317949% change)
#     iteration   64: trace = 0.2277582045530395 (0.00313652% change)
#     iteration   65: trace = 0.2277511367049045 (0.00310327% change)
#     iteration   66: trace = 0.2277441211281986 (0.00308042% change)
#     iteration   67: trace = 0.2277371324449866 (0.0030687% change)
#     iteration   68: trace = 0.227730143258516 (0.00306902% change)
#     iteration   69: trace = 0.2277231237039786 (0.00308245% change)
#     resetting CG direction...
#     large trace change predicted (1.25078%)
#     iteration   70: trace = 0.2249358764156694 (1.2315% change)
#     iteration   71: trace = 0.2241025431664408 (0.371163% change)
#     iteration   72: trace = 0.2239808188046715 (0.0543311% change)
#     iteration   73: trace = 0.2239556092775632 (0.0112559% change)
#     iteration   74: trace = 0.2239476401184363 (0.00355843% change)
#     iteration   75: trace = 0.2239443156303578 (0.0014845% change)
#     iteration   76: trace = 0.2239418089270353 (0.00111935% change)
#     iteration   77: trace = 0.2239406609115555 (0.000512641% change)
#     iteration   78: trace = 0.2239400074014039 (0.000291823% change)
#     iteration   79: trace = 0.223939702734042 (0.000136049% change)
#     iteration   80: trace = 0.223939577188658 (5.60622e-05% change)
#     iteration   81: trace = 0.2239395134906691 (2.84443e-05% change)
#     iteration   82: trace = 0.2239395049326043 (3.8216e-06% change)
# Finished solving for bands 1 to 4 after 82 iterations.
# zevenfreqs:, 5, 0.222222, 0, 0, 0.222222, 0.210085, 0.231381, 0.237535, 0.264279
# elapsed time for k point: 15.227537870407104
# solve_kpoint (0.277778,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.3200451892777462 (0.416605% change)
#     iteration    2: trace = 0.3197942043866108 (0.0784525% change)
#     iteration    3: trace = 0.319701810011605 (0.028896% change)
#     iteration    4: trace = 0.3196705592018464 (0.00977546% change)
#     iteration    5: trace = 0.3196629818189197 (0.0023704% change)
#     iteration    6: trace = 0.3196614051627799 (0.000493226% change)
#     iteration    7: trace = 0.3196609833795929 (0.000131947% change)
#     iteration    8: trace = 0.3196608541134632 (4.04385e-05% change)
#     iteration    9: trace = 0.3196608288036124 (7.91772e-06% change)
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 6, 0.277778, 0, 0, 0.277778, 0.250107, 0.282663, 0.287761, 0.307251
# elapsed time for k point: 1.8175523281097412
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.433595525392593 (0.477846% change)
#     iteration    2: trace = 0.4327013651835536 (0.206433% change)
#     iteration    3: trace = 0.4321635556222213 (0.124368% change)
#     iteration    4: trace = 0.431992664912395 (0.0395509% change)
#     iteration    5: trace = 0.4319452968860894 (0.0109656% change)
#     iteration    6: trace = 0.4319324153812551 (0.00298225% change)
#     iteration    7: trace = 0.4319290701494922 (0.000774483% change)
#     iteration    8: trace = 0.4319281821639436 (0.000205586% change)
#     iteration    9: trace = 0.4319279834566661 (4.60047e-05% change)
#     iteration   10: trace = 0.4319279507915976 (7.56262e-06% change)
# Finished solving for bands 1 to 4 after 10 iterations.
# zevenfreqs:, 7, 0.333333, 0, 0, 0.333333, 0.284016, 0.334502, 0.336348, 0.355305
# elapsed time for k point: 2.0051839351654053
# solve_kpoint (0.388889,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.5561913779545804 (0.755804% change)
#     iteration    2: trace = 0.5538171823443728 (0.42778% change)
#     iteration    3: trace = 0.552891905614409 (0.167212% change)
#     iteration    4: trace = 0.5526704093568949 (0.0400694% change)
#     iteration    5: trace = 0.5526021592910704 (0.0123499% change)
#     iteration    6: trace = 0.5525748725355949 (0.00493799% change)
#     iteration    7: trace = 0.5525601911029856 (0.00265695% change)
#     iteration    8: trace = 0.5525506854956793 (0.0017203% change)
#     iteration    9: trace = 0.5525462206665677 (0.000808043% change)
#     iteration   10: trace = 0.5525450736039214 (0.000207596% change)
#     iteration   11: trace = 0.5525447751990672 (5.40055e-05% change)
#     iteration   12: trace = 0.5525446915210495 (1.51441e-05% change)
#     iteration   13: trace = 0.5525446794729214 (2.18048e-06% change)
# Finished solving for bands 1 to 4 after 13 iterations.
# zevenfreqs:, 8, 0.388889, 0, 0, 0.388889, 0.314674, 0.370126, 0.390643, 0.404882
# elapsed time for k point: 2.5596179962158203
# solve_kpoint (0.444444,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.6738971783047889 (1.4509% change)
#     large trace change predicted (3.55451%)
#     iteration    2: trace = 0.6585445547328 (2.30443% change)
#     iteration    3: trace = 0.6484323202328125 (1.54742% change)
#     iteration    4: trace = 0.6438280000847376 (0.712599% change)
#     iteration    5: trace = 0.6418071051483673 (0.314381% change)
#     iteration    6: trace = 0.6410076306611534 (0.124644% change)
#     iteration    7: trace = 0.6406399526601068 (0.0573758% change)
#     iteration    8: trace = 0.6404267395008794 (0.0332868% change)
#     iteration    9: trace = 0.6402907507949086 (0.0212363% change)
#     iteration   10: trace = 0.6402050149765336 (0.013391% change)
#     iteration   11: trace = 0.6401562751665674 (0.00761345% change)
#     iteration   12: trace = 0.6401296225674535 (0.00416354% change)
#     iteration   13: trace = 0.640120371682771 (0.00144517% change)
#     iteration   14: trace = 0.6401163386959881 (0.000630038% change)
#     iteration   15: trace = 0.6401149857814724 (0.000211355% change)
#     iteration   16: trace = 0.640114659019927 (5.10473e-05% change)
#     iteration   17: trace = 0.6401144575438846 (3.1475e-05% change)
#     iteration   18: trace = 0.6401143415376125 (1.81227e-05% change)
#     iteration   19: trace = 0.6401143144623848 (4.22975e-06% change)
# Finished solving for bands 1 to 4 after 19 iterations.
# zevenfreqs:, 9, 0.444444, 0, 0, 0.444444, 0.342327, 0.397301, 0.408268, 0.445416
# elapsed time for k point: 3.6121299266815186
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.7088345779220175 (0.822508% change)
#     iteration    2: trace = 0.7060328931259221 (0.396035% change)
#     large trace change predicted (0.958892%)
#     iteration    3: trace = 0.6999446866976726 (0.866046% change)
#     iteration    4: trace = 0.6927540006594511 (1.03263% change)
#     iteration    5: trace = 0.6901344424230674 (0.378853% change)
#     iteration    6: trace = 0.6883585806459547 (0.257653% change)
#     near maximum in trace
#     iteration    7: trace = 0.6809958991062923 (1.07535% change)
#     iteration    8: trace = 0.6758768781656908 (0.754532% change)
#     iteration    9: trace = 0.6680331754168407 (1.1673% change)
#     iteration   10: trace = 0.6537702629537887 (2.1581% change)
#     iteration   11: trace = 0.6456327497704921 (1.2525% change)
#     iteration   12: trace = 0.6425327089877803 (0.481311% change)
#     iteration   13: trace = 0.6411964783767961 (0.20818% change)
#     iteration   14: trace = 0.6410009267451305 (0.0305026% change)
#     iteration   15: trace = 0.6409453899577161 (0.00866445% change)
#     iteration   16: trace = 0.6409320111372762 (0.00208738% change)
#     iteration   17: trace = 0.6409297647444343 (0.000350489% change)
#     iteration   18: trace = 0.6409290299822777 (0.00011464% change)
#     iteration   19: trace = 0.6409289374714211 (1.44339e-05% change)
#     iteration   20: trace = 0.6409289176575907 (3.09142e-06% change)
# Finished solving for bands 1 to 4 after 20 iterations.
# zevenfreqs:, 10, 0.5, 0, 0, 0.5, 0.358635, 0.393711, 0.41635, 0.428899
# elapsed time for k point: 3.8546528816223145
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3586345159107606 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.08972805620893108 at Vector3<0.0, 0.0, 0.0> to 0.39730097739877573 at Vector3<0.4444444444444444, 0.0, 0.0>
# Band 3 range: 0.09324952104624358 at Vector3<0.0, 0.0, 0.0> to 0.4163503549039332 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.16818452083351557 at Vector3<0.0, 0.0, 0.0> to 0.4454159694238692 at Vector3<0.4444444444444444, 0.0, 0.0>
# total elapsed time for run: 37.91672110557556
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.531915,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 10 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08533811569213867
# solve_kpoint (0,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 2 to 4...
#     near maximum in trace
#     iteration    1: trace = 0.4579948914069398 (199.094% change)
#     iteration    2: trace = 0.05624366566918108 (156.251% change)
#     iteration    3: trace = 0.05327165553412935 (5.42757% change)
#     iteration    4: trace = 0.0525412085054003 (1.38064% change)
#     iteration    5: trace = 0.0521884604387808 (0.673635% change)
#     iteration    6: trace = 0.0520781375015356 (0.211617% change)
#     iteration    7: trace = 0.05205353879902908 (0.0472454% change)
#     iteration    8: trace = 0.05204591263234757 (0.0146517% change)
#     large trace change predicted (0.0591153%)
#     iteration    9: trace = 0.05201514855918531 (0.059127% change)
#     iteration   10: trace = 0.05195702622308845 (0.111804% change)
#     iteration   11: trace = 0.05194474534220037 (0.0236394% change)
#     iteration   12: trace = 0.05194204354321363 (0.00520143% change)
#     iteration   13: trace = 0.05194119269745209 (0.00163808% change)
#     iteration   14: trace = 0.05194082640915788 (0.000705201% change)
#     iteration   15: trace = 0.05194077384681016 (0.000101197% change)
#     iteration   16: trace = 0.05194076916944951 (9.00518e-06% change)
# Finished solving for bands 2 to 4 after 16 iterations.
# zoddfreqs:, 1, 0, 0, 0, 0, 0, 0.0925793, 0.0937114, 0.185979
# elapsed time for k point: 2.6051790714263916
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.064020172144229 (0.0414259% change)
#     iteration    2: trace = 0.06400509918447003 (0.0235469% change)
#     large trace change predicted (0.0811939%)
#     iteration    3: trace = 0.06395353055920591 (0.080602% change)
#     iteration    4: trace = 0.06391975621428861 (0.0528247% change)
#     iteration    5: trace = 0.06390138213685716 (0.0287497% change)
#     iteration    6: trace = 0.06388836347696346 (0.0203751% change)
#     iteration    7: trace = 0.06388533453785317 (0.0047411% change)
#     iteration    8: trace = 0.0638847831250943 (0.000863133% change)
#     iteration    9: trace = 0.0638847154531251 (0.000105928% change)
#     iteration   10: trace = 0.06388465853807967 (8.90903e-05% change)
#     large trace change predicted (0.000647288%)
#     iteration   11: trace = 0.06388424485832567 (0.000647544% change)
#     iteration   12: trace = 0.06388356962447717 (0.00105697% change)
#     iteration   13: trace = 0.06388317406813296 (0.000619185% change)
#     iteration   14: trace = 0.06388289367919174 (0.00043891% change)
#     iteration   15: trace = 0.06388277423739128 (0.00018697% change)
#     iteration   16: trace = 0.06388275686018573 (2.72017e-05% change)
#     iteration   17: trace = 0.06388275410282415 (4.31628e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zoddfreqs:, 2, 0.0555556, 0, 0, 0.0555556, 0.0550459, 0.107512, 0.108849, 0.193509
# elapsed time for k point: 3.3147308826446533
# solve_kpoint (0.111111,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.09972288977007726 (0.106028% change)
#     iteration    2: trace = 0.09969335473970641 (0.0296215% change)
#     iteration    3: trace = 0.09966483832948253 (0.0286082% change)
#     iteration    4: trace = 0.09964927676120841 (0.0156151% change)
#     iteration    5: trace = 0.09963721670669745 (0.0121032% change)
#     iteration    6: trace = 0.09962244555290589 (0.014826% change)
#     iteration    7: trace = 0.0996119231716331 (0.0105628% change)
#     iteration    8: trace = 0.09960863391210738 (0.00330213% change)
#     iteration    9: trace = 0.09960833275263556 (0.000302343% change)
#     iteration   10: trace = 0.09960830189268705 (3.09813e-05% change)
#     iteration   11: trace = 0.09960829809560573 (3.81201e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 3, 0.111111, 0, 0, 0.111111, 0.10999, 0.143189, 0.145059, 0.214395
# elapsed time for k point: 2.1542739868164062
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.1588781449737562 (0.154638% change)
#     iteration    2: trace = 0.1588168501724792 (0.0385872% change)
#     iteration    3: trace = 0.1587773108542019 (0.0248993% change)
#     iteration    4: trace = 0.1587602984359399 (0.0107152% change)
#     iteration    5: trace = 0.1587536880301926 (0.00416385% change)
#     iteration    6: trace = 0.158750408482572 (0.00206583% change)
#     iteration    7: trace = 0.1587471870861963 (0.00202924% change)
#     iteration    8: trace = 0.1587436867291306 (0.00220501% change)
#     iteration    9: trace = 0.1587428025041827 (0.000557016% change)
#     iteration   10: trace = 0.1587426834581588 (7.4993e-05% change)
#     iteration   11: trace = 0.158742667326864 (1.01619e-05% change)
#     iteration   12: trace = 0.1587426649951522 (1.46886e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 4, 0.166667, 0, 0, 0.166667, 0.164662, 0.187995, 0.190652, 0.244824
# elapsed time for k point: 2.3384456634521484
# solve_kpoint (0.222222,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.2408015423950659 (0.193318% change)
#     iteration    2: trace = 0.2406938439903822 (0.044735% change)
#     iteration    3: trace = 0.24063834232332 (0.0230617% change)
#     iteration    4: trace = 0.2406134760262727 (0.010334% change)
#     iteration    5: trace = 0.240603668006941 (0.00407634% change)
#     iteration    6: trace = 0.2406011217547025 (0.00105828% change)
#     iteration    7: trace = 0.2406002966474987 (0.000342936% change)
#     iteration    8: trace = 0.2405997541782753 (0.000225465% change)
#     iteration    9: trace = 0.2405991775583884 (0.00023966% change)
#     iteration   10: trace = 0.2405989324899694 (0.000101858% change)
#     iteration   11: trace = 0.2405988816729823 (2.1121e-05% change)
#     iteration   12: trace = 0.2405988734663155 (3.41093e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 5, 0.222222, 0, 0, 0.222222, 0.218659, 0.236598, 0.24026, 0.281218
# elapsed time for k point: 2.366389036178589
# solve_kpoint (0.277778,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.3444805811623149 (0.227038% change)
#     iteration    2: trace = 0.3443191205790965 (0.0468817% change)
#     iteration    3: trace = 0.3442557625796285 (0.0184026% change)
#     iteration    4: trace = 0.3442292546888784 (0.00770035% change)
#     iteration    5: trace = 0.34421735863563 (0.00345591% change)
#     iteration    6: trace = 0.3442136598178204 (0.00107456% change)
#     iteration    7: trace = 0.3442125310302652 (0.000327933% change)
#     iteration    8: trace = 0.3442122113482125 (9.28735e-05% change)
#     iteration    9: trace = 0.3442121216370559 (2.60628e-05% change)
#     iteration   10: trace = 0.3442120683438135 (1.54827e-05% change)
#     iteration   11: trace = 0.3442120311607407 (1.08024e-05% change)
#     iteration   12: trace = 0.3442120150993861 (4.66612e-06% change)
# Finished solving for bands 1 to 4 after 12 iterations.
# zoddfreqs:, 6, 0.277778, 0, 0, 0.277778, 0.270901, 0.28706, 0.291657, 0.321492
# elapsed time for k point: 2.3064467906951904
# solve_kpoint (0.333333,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.4686568368260486 (0.260362% change)
#     iteration    2: trace = 0.4684034595695508 (0.0540792% change)
#     iteration    3: trace = 0.4683075953583854 (0.0204683% change)
#     iteration    4: trace = 0.46827134403006 (0.00774122% change)
#     iteration    5: trace = 0.468257555137101 (0.00294468% change)
#     iteration    6: trace = 0.4682535455994166 (0.000856271% change)
#     iteration    7: trace = 0.4682523202683766 (0.000261681% change)
#     iteration    8: trace = 0.4682518940193955 (9.10298e-05% change)
#     iteration    9: trace = 0.4682517593929351 (2.87509e-05% change)
#     iteration   10: trace = 0.4682517106479829 (1.041e-05% change)
#     iteration   11: trace = 0.4682516860203121 (5.25949e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 7, 0.333333, 0, 0, 0.333333, 0.319163, 0.339125, 0.343488, 0.365236
# elapsed time for k point: 2.116117000579834
# solve_kpoint (0.388889,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.6111631848359664 (0.326136% change)
#     iteration    2: trace = 0.6105366760660882 (0.102563% change)
#     iteration    3: trace = 0.6100954865968459 (0.0722887% change)
#     iteration    4: trace = 0.6098871980365257 (0.0341462% change)
#     iteration    5: trace = 0.6098115039948869 (0.0124119% change)
#     iteration    6: trace = 0.6097893470525042 (0.00363347% change)
#     iteration    7: trace = 0.6097829871443883 (0.00104297% change)
#     iteration    8: trace = 0.6097810566859689 (0.000316582% change)
#     iteration    9: trace = 0.6097805380288535 (8.50563e-05% change)
#     iteration   10: trace = 0.609780419443211 (1.94473e-05% change)
#     iteration   11: trace = 0.6097803802784443 (6.42277e-06% change)
# Finished solving for bands 1 to 4 after 11 iterations.
# zoddfreqs:, 8, 0.388889, 0, 0, 0.388889, 0.361666, 0.392708, 0.393067, 0.412622
# elapsed time for k point: 2.1376760005950928
# solve_kpoint (0.444444,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.7644359204067663 (0.53289% change)
#     iteration    2: trace = 0.7624540638376265 (0.259594% change)
#     iteration    3: trace = 0.7611106893367359 (0.176346% change)
#     iteration    4: trace = 0.7606715141716518 (0.0577185% change)
#     iteration    5: trace = 0.7605445821508547 (0.0166882% change)
#     iteration    6: trace = 0.7604985871926939 (0.00604782% change)
#     iteration    7: trace = 0.7604724944838729 (0.00343106% change)
#     iteration    8: trace = 0.7604395658236063 (0.00433012% change)
#     large trace change predicted (0.0124489%)
#     iteration    9: trace = 0.7603459576418636 (0.0123105% change)
#     large trace change predicted (0.0272184%)
#     iteration   10: trace = 0.7601485330788024 (0.0259685% change)
#     iteration   11: trace = 0.7598688971630697 (0.0367938% change)
#     iteration   12: trace = 0.7597083134744079 (0.0211353% change)
#     iteration   13: trace = 0.7596556904287685 (0.00692698% change)
#     iteration   14: trace = 0.759627103932681 (0.00376316% change)
#     iteration   15: trace = 0.7596161146404425 (0.00144668% change)
#     iteration   16: trace = 0.7596121528739551 (0.00052155% change)
#     iteration   17: trace = 0.7596103220044254 (0.000241027% change)
#     iteration   18: trace = 0.7596092225023068 (0.000144746% change)
#     iteration   19: trace = 0.7596082909827255 (0.000122631% change)
#     iteration   20: trace = 0.7596072004055979 (0.000143571% change)
#     large trace change predicted (0.000298357%)
#     iteration   21: trace = 0.7596049340421249 (0.00029836% change)
#     large trace change predicted (0.00137447%)
#     iteration   22: trace = 0.7595947294511638 (0.00134342% change)
#     near maximum in trace
#     iteration   23: trace = 0.7595026701425494 (0.0121203% change)
#     iteration   24: trace = 0.7594821359638761 (0.00270367% change)
#     iteration   25: trace = 0.7594650912716282 (0.00224428% change)
#     iteration   26: trace = 0.7594500325059912 (0.00198283% change)
#     iteration   27: trace = 0.7594362735187634 (0.00181172% change)
#     iteration   28: trace = 0.7594234401927211 (0.00168986% change)
#     iteration   29: trace = 0.7594112831987172 (0.00160083% change)
#     iteration   30: trace = 0.7593996066135102 (0.0015376% change)
#     iteration   31: trace = 0.7593882423544164 (0.00149649% change)
#     iteration   32: trace = 0.7593770428244585 (0.00147482% change)
#     iteration   33: trace = 0.7593658796675486 (0.00147005% change)
#     iteration   34: trace = 0.7593546437400369 (0.00147966% change)
#     iteration   35: trace = 0.7593432449199513 (0.00150113% change)
#     iteration   36: trace = 0.7593316118798117 (0.001532% change)
#     iteration   37: trace = 0.7593196923746905 (0.00156975% change)
#     iteration   38: trace = 0.7593074544312929 (0.00161171% change)
#     iteration   39: trace = 0.7592948882612409 (0.00165497% change)
#     iteration   40: trace = 0.7592820078762429 (0.00169638% change)
#     iteration   41: trace = 0.7592688505402426 (0.00173288% change)
#     iteration   42: trace = 0.7592554719747613 (0.00176205% change)
#     iteration   43: trace = 0.7592419363728233 (0.00178276% change)
#     iteration   44: trace = 0.7592283028327442 (0.00179569% change)
#     iteration   45: trace = 0.7592146124714065 (0.00180321% change)
#     iteration   46: trace = 0.7592008811764266 (0.00180863% change)
#     iteration   47: trace = 0.7591871009025871 (0.00181512% change)
#     iteration   48: trace = 0.7591732489652332 (0.00182459% change)
#     iteration   49: trace = 0.759159302019758 (0.00183714% change)
#     iteration   50: trace = 0.7591452503247118 (0.00185097% change)
#     iteration   51: trace = 0.7591311082143994 (0.00186292% change)
#     iteration   52: trace = 0.7591169179543515 (0.00186929% change)
#     iteration   53: trace = 0.7591027460588257 (0.00186691% change)
#     iteration   54: trace = 0.7590886733680615 (0.00185388% change)
#     iteration   55: trace = 0.7590747819767922 (0.00183003% change)
#     iteration   56: trace = 0.7590611426871385 (0.00179685% change)
#     iteration   57: trace = 0.7590478058439618 (0.00175703% change)
#     iteration   58: trace = 0.7590347967935154 (0.00171388% change)
#     iteration   59: trace = 0.7590221156625863 (0.00167071% change)
#     iteration   60: trace = 0.7590097402453444 (0.00163046% change)
#     iteration   61: trace = 0.7589976305705199 (0.00159547% change)
#     iteration   62: trace = 0.7589857339619732 (0.00156742% change)
#     iteration   63: trace = 0.7589739898149478 (0.00154736% change)
#     iteration   64: trace = 0.7589623336970122 (0.00153578% change)
#     iteration   65: trace = 0.7589507006635358 (0.00153277% change)
#     iteration   66: trace = 0.7589390278439641 (0.00153803% change)
#     iteration   67: trace = 0.7589272564313165 (0.00155105% change)
#     iteration   68: trace = 0.7589153332248459 (0.00157107% change)
#     iteration   69: trace = 0.7589032118588219 (0.00159721% change)
#     resetting CG direction...
#     large trace change predicted (0.152893%)
#     iteration   70: trace = 0.7577354647623312 (0.153991% change)
#     iteration   71: trace = 0.7572226775619043 (0.0676966% change)
#     iteration   72: trace = 0.7569773160819383 (0.0324081% change)
#     iteration   73: trace = 0.7568534364845649 (0.0163664% change)
#     iteration   74: trace = 0.7567942660430761 (0.00781826% change)
#     iteration   75: trace = 0.7567270158394311 (0.00888659% change)
#     iteration   76: trace = 0.75670862769122 (0.00242999% change)
#     iteration   77: trace = 0.7567037005492412 (0.00065113% change)
#     iteration   78: trace = 0.7567016302401303 (0.000273596% change)
#     iteration   79: trace = 0.7567000842611026 (0.000204305% change)
#     iteration   80: trace = 0.7566988189034077 (0.000167221% change)
#     iteration   81: trace = 0.7566977372265137 (0.000142947% change)
#     iteration   82: trace = 0.7566966665984988 (0.000141487% change)
#     iteration   83: trace = 0.7566953069237558 (0.000179686% change)
#     iteration   84: trace = 0.7566946897360434 (8.15636e-05% change)
#     iteration   85: trace = 0.7566945192769181 (2.25268e-05% change)
#     iteration   86: trace = 0.7566944531162075 (8.74338e-06% change)
# Finished solving for bands 1 to 4 after 86 iterations.
# zoddfreqs:, 9, 0.444444, 0, 0, 0.444444, 0.398838, 0.432777, 0.44715, 0.458676
# elapsed time for k point: 16.21051812171936
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
#     iteration    1: trace = 0.9147701624161163 (0.460894% change)
#     iteration    2: trace = 0.9132411782790131 (0.167284% change)
#     near maximum in trace
#     iteration    3: trace = 0.8948355279692488 (2.03594% change)
#     iteration    4: trace = 0.8903941966988351 (0.497564% change)
#     iteration    5: trace = 0.8781966842825729 (1.37935% change)
#     iteration    6: trace = 0.8654453773232705 (1.46261% change)
#     iteration    7: trace = 0.8430765818464816 (2.6185% change)
#     iteration    8: trace = 0.8253142139945446 (2.12928% change)
#     iteration    9: trace = 0.8144170999903326 (1.32913% change)
#     iteration   10: trace = 0.8062828963177603 (1.00379% change)
#     iteration   11: trace = 0.8037938447499298 (0.309184% change)
#     iteration   12: trace = 0.803152053782202 (0.0798771% change)
#     iteration   13: trace = 0.8029824191369371 (0.0211233% change)
#     iteration   14: trace = 0.8029545405141837 (0.00347194% change)
#     iteration   15: trace = 0.8029414077289043 (0.00163557% change)
#     iteration   16: trace = 0.8029379953462967 (0.000424986% change)
#     iteration   17: trace = 0.802937247559782 (9.31313e-05% change)
#     iteration   18: trace = 0.8029370100579618 (2.95791e-05% change)
#     iteration   19: trace = 0.8029369765649921 (4.17131e-06% change)
# Finished solving for bands 1 to 4 after 19 iterations.
# zoddfreqs:, 10, 0.5, 0, 0, 0.5, 0.429642, 0.434715, 0.462216, 0.464462
# elapsed time for k point: 3.692089080810547
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.42964153147312295 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.09257927751280907 at Vector3<0.0, 0.0, 0.0> to 0.43471483362399677 at Vector3<0.5, 0.0, 0.0>
# Band 3 range: 0.0937113902610787 at Vector3<0.0, 0.0, 0.0> to 0.4622155994658027 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.18597855220425508 at Vector3<0.0, 0.0, 0.0> to 0.464461929587509 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 39.327913999557495
# done

# %% [markdown]
# ### Understanding the outputs
#
# - `kpts` — shape `(n_k, 3)`: full 3-D k-vectors
# - `kpar` — shape `(n_k,)`: magnitude of in-plane k
# - `zeven_freqs` — shape `(n_k, num_bands)`: TE-like frequencies in c/a
# - `zodd_freqs` — shape `(n_k, num_bands)`: TM-like frequencies in c/a

# %%
print("k-points shape:", kpts.shape)
print("kpar shape:    ", kpar.shape)
print("TE freqs shape:", zeven_freqs.shape)
print("TM freqs shape:", zodd_freqs.shape)
# Out:
# k-points shape: (10, 3)
# kpar shape:     (10,)
# TE freqs shape: (10, 4)
# TM freqs shape: (10, 4)

# %% [markdown]
# ## 3 — Unit Conversions
#
# The class provides helpers to convert between normalised frequency (c/a), THz, and Hz.

# %%
# Normalised → THz
freq_THz = sim.freq_norm_to_THz(zeven_freqs)
print("TE band 0 at k=π/a:", freq_THz[-1, 0], "THz")

# Normalised → Hz
freq_Hz = sim.freq_norm_to_Hz(zeven_freqs)

# Hz → Normalised (round-trip)
freq_norm = sim.freq_Hz_to_norm(freq_Hz)
print("Round-trip error:", np.max(np.abs(freq_norm - zeven_freqs)))
# Out:
# TE band 0 at k=π/a: 228.75728308197245 THz
# Round-trip error: 2.7755575615628914e-17

# %% [markdown]
# ## 4 — Plotting the Band Structure
#
# ### 4.1 — Normalised units

# %%
fig, ax = sim.plot_bands(
    units='norm',
    title='Silicon nanobeam — circular holes',
)

# %% [markdown]
# ### 4.2 — THz units with a target frequency

# %%
wavelength = 1.324
f_target = C0 / wavelength

fig, ax = sim.plot_bands(
    units='THz',
    freq0_Hz=f_target,
    ylim=(100, 300),
    title='Band structure around telecom C-band',
)

# %% [markdown]
# ## 5 — Visualising the Dielectric Profile
#
# After running any simulation you can inspect the permittivity cross-section at z = 0.
# The `periods` argument controls how many unit cells are shown.

# %%
fig, ax = sim.plot_epsilon(periods=5)
# Out:
# epsilon: 1-4, mean 1.05384, harm. mean 1.01406, 1.9% > 1, 1.79455% "fill"
# real part range: 1 .. 4

# %% [markdown]
# ## 6 — Single k-point Calculation
#
# Use `run_at_k()` when you only need the frequencies at one wavevector.
# This is much faster than a full band structure and is handy inside optimisation loops.

# %%
kpts, kpar, zeven, zodd = sim.run_at_k(kx=0.5)

print("TE-like frequencies at k = π/a:", zeven)
print("TM-like frequencies at k = π/a:", zodd)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.531915,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1015172004699707
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.433365146315937 (189.349% change)
#     iteration    2: trace = 1.097552587913832 (148.538% change)
#     iteration    3: trace = 0.8018851261708525 (31.1321% change)
#     iteration    4: trace = 0.7255329903146962 (9.99754% change)
#     iteration    5: trace = 0.6851343977968898 (5.72759% change)
#     iteration    6: trace = 0.6560214170132552 (4.34148% change)
#     iteration    7: trace = 0.6442959824188873 (1.80347% change)
#     iteration    8: trace = 0.6417048347639822 (0.402978% change)
#     iteration    9: trace = 0.641073717721014 (0.0983984% change)
#     iteration   10: trace = 0.6409598452508358 (0.0177644% change)
#     iteration   11: trace = 0.6409354945190369 (0.00379918% change)
#     iteration   12: trace = 0.640930346784917 (0.000803163% change)
#     iteration   13: trace = 0.6409292500147362 (0.000171122% change)
#     iteration   14: trace = 0.6409289861078387 (4.11757e-05% change)
#     iteration   15: trace = 0.6409289245184302 (9.6094e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.358635, 0.393711, 0.41635, 0.428899
# elapsed time for k point: 2.973116159439087
# total elapsed time for run: 3.0747268199920654
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.531915,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.265957..0.265957, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.531915,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09288883209228516
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 8.122841094419986 (188.411% change)
#     iteration    2: trace = 1.33242072658938 (143.633% change)
#     iteration    3: trace = 1.01551257079073 (26.9946% change)
#     iteration    4: trace = 0.902070790710404 (11.8317% change)
#     iteration    5: trace = 0.8470076529092897 (6.29625% change)
#     iteration    6: trace = 0.8188723081166515 (3.37784% change)
#     iteration    7: trace = 0.8079550085973783 (1.34216% change)
#     iteration    8: trace = 0.8046768178277838 (0.406564% change)
#     iteration    9: trace = 0.8034716866186393 (0.149878% change)
#     iteration   10: trace = 0.8031194334531966 (0.043851% change)
#     iteration   11: trace = 0.8029925608107773 (0.0157987% change)
#     iteration   12: trace = 0.8029526548127476 (0.00496978% change)
#     iteration   13: trace = 0.8029416394317935 (0.00137187% change)
#     iteration   14: trace = 0.802938232687609 (0.000424284% change)
#     iteration   15: trace = 0.802937345099759 (0.000110543% change)
#     iteration   16: trace = 0.8029370720694391 (3.40039e-05% change)
#     iteration   17: trace = 0.8029369968128359 (9.37267e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.429642, 0.434715, 0.462216, 0.464462
# elapsed time for k point: 3.3631842136383057
# total elapsed time for run: 3.4561359882354736
# done
# TE-like frequencies at k = π/a: [[0.35863452 0.39371074 0.41635036 0.4288991 ]]
# TM-like frequencies at k = π/a: [[0.42964153 0.43471484 0.4622156  0.46446194]]

# %% [markdown]
# ## 7 — Parameter Sweeps (1-D)
#
# Investigate how band frequencies change as you vary a single geometric parameter.
#
# ### Available `param_name` values
#
# | `param_name` | What it sweeps |
# |---|---|
# | `'p1'` | First hole parameter (diameter for circular, x-size for ellipse/square) |
# | `'p2'` | Second hole parameter (y-size for ellipse/square) |
# | `'Lx'` | Lattice constant |
# | `'Ly'` | Slab width |
# | `'thickness'` | Slab thickness |

# %% [markdown]
# ### 7.1 — Sweep the hole diameter

# %%
diameters = np.linspace(0.15, 0.3, 10)  # µm

sweep = sim.run_sweep(
    param_name='p1',
    param_values_um=diameters,
    kx=0.5,  # evaluate at the band edge
)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.319149,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09372305870056152
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.699210374784112 (188.964% change)
#     iteration    2: trace = 1.209693645511253 (145.686% change)
#     iteration    3: trace = 0.8524685369014804 (34.6457% change)
#     iteration    4: trace = 0.7412490748500435 (13.9572% change)
#     iteration    5: trace = 0.6857272762248547 (7.78174% change)
#     iteration    6: trace = 0.6430813471467283 (6.41867% change)
#     iteration    7: trace = 0.6242935898412448 (2.96483% change)
#     iteration    8: trace = 0.6191759417724391 (0.823124% change)
#     iteration    9: trace = 0.6177109404221145 (0.236885% change)
#     iteration   10: trace = 0.6174460274340332 (0.0428954% change)
#     iteration   11: trace = 0.6173862204981639 (0.00968665% change)
#     iteration   12: trace = 0.6173739001035757 (0.00199559% change)
#     iteration   13: trace = 0.6173715813361348 (0.000375586% change)
#     iteration   14: trace = 0.6173710220400296 (9.05931e-05% change)
#     iteration   15: trace = 0.6173709078797808 (1.84914e-05% change)
#     iteration   16: trace = 0.6173708865573182 (3.45375e-06% change)
# Finished solving for bands 1 to 4 after 16 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.353458, 0.377791, 0.411672, 0.424545
# elapsed time for k point: 3.216968059539795
# total elapsed time for run: 3.3108060359954834
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.319149,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.159574..0.159574, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.319149,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09621906280517578
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.656642690553192 (189.044% change)
#     iteration    2: trace = 1.266988626174369 (143.207% change)
#     iteration    3: trace = 0.968684636575082 (26.6858% change)
#     iteration    4: trace = 0.8742880396559704 (10.2439% change)
#     iteration    5: trace = 0.8353322128914333 (4.55725% change)
#     iteration    6: trace = 0.8129592950719773 (2.71468% change)
#     iteration    7: trace = 0.8019084398923455 (1.36864% change)
#     iteration    8: trace = 0.7974778611004695 (0.554035% change)
#     iteration    9: trace = 0.7955305791114098 (0.244479% change)
#     iteration   10: trace = 0.7948978068027907 (0.0795726% change)
#     iteration   11: trace = 0.7946919507141714 (0.0259005% change)
#     iteration   12: trace = 0.7946404178438384 (0.00648485% change)
#     iteration   13: trace = 0.7946275969741755 (0.00161343% change)
#     iteration   14: trace = 0.7946237125269013 (0.00048884% change)
#     iteration   15: trace = 0.7946226006758283 (0.000139922% change)
#     iteration   16: trace = 0.794622249111526 (4.42429e-05% change)
#     iteration   17: trace = 0.7946221639188017 (1.07212e-05% change)
#     iteration   18: trace = 0.7946221432553626 (2.60041e-06% change)
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.427026, 0.429792, 0.461377, 0.463336
# elapsed time for k point: 3.5601701736450195
# total elapsed time for run: 3.6564648151397705
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.35461,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09863400459289551
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.714520293523724 (188.954% change)
#     iteration    2: trace = 1.153344583984793 (147.976% change)
#     iteration    3: trace = 0.8251529166882472 (33.1758% change)
#     iteration    4: trace = 0.7080755177462605 (15.272% change)
#     iteration    5: trace = 0.6519435562515745 (8.25458% change)
#     iteration    6: trace = 0.6300515801351262 (3.4153% change)
#     iteration    7: trace = 0.6232716190287679 (1.08192% change)
#     iteration    8: trace = 0.62164576714382 (0.261198% change)
#     iteration    9: trace = 0.6212189088282379 (0.0686894% change)
#     iteration   10: trace = 0.6211375959023661 (0.0130901% change)
#     iteration   11: trace = 0.6211178042691416 (0.0031864% change)
#     iteration   12: trace = 0.6211136184720648 (0.000673916% change)
#     iteration   13: trace = 0.6211128336445716 (0.000126358% change)
#     iteration   14: trace = 0.6211126708922586 (2.62033e-05% change)
#     iteration   15: trace = 0.6211126481426141 (3.66272e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.353986, 0.380519, 0.412357, 0.425411
# elapsed time for k point: 2.98459529876709
# total elapsed time for run: 3.083292007446289
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.35461,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.177305..0.177305, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.35461,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08974123001098633
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 8.060487905649051 (188.467% change)
#     iteration    2: trace = 1.27783871605573 (145.265% change)
#     iteration    3: trace = 0.9563006202648909 (28.7841% change)
#     iteration    4: trace = 0.8728647082701539 (9.12284% change)
#     iteration    5: trace = 0.8361186269097965 (4.30034% change)
#     iteration    6: trace = 0.8126148165300389 (2.85114% change)
#     iteration    7: trace = 0.8016466317821176 (1.35891% change)
#     iteration    8: trace = 0.7980012002054679 (0.455779% change)
#     iteration    9: trace = 0.7965682687620451 (0.179726% change)
#     iteration   10: trace = 0.7961556844767087 (0.0518086% change)
#     iteration   11: trace = 0.7960212587997405 (0.0168858% change)
#     iteration   12: trace = 0.7959827356558683 (0.00483958% change)
#     iteration   13: trace = 0.7959726702238301 (0.00126454% change)
#     iteration   14: trace = 0.7959692994595607 (0.000423478% change)
#     iteration   15: trace = 0.795968329478589 (0.000121862% change)
#     iteration   16: trace = 0.7959680315317237 (3.7432e-05% change)
#     iteration   17: trace = 0.7959679540818384 (9.73028e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.427406, 0.430666, 0.461474, 0.46353
# elapsed time for k point: 3.299107074737549
# total elapsed time for run: 3.3889100551605225
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.390071,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08795809745788574
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.665559251543744 (189.02% change)
#     iteration    2: trace = 1.168062150366502 (147.108% change)
#     iteration    3: trace = 0.7979804582663803 (37.6474% change)
#     iteration    4: trace = 0.6870654010170674 (14.9376% change)
#     iteration    5: trace = 0.6454806065703882 (6.2414% change)
#     iteration    6: trace = 0.6300811482233033 (2.41454% change)
#     iteration    7: trace = 0.6261206536228409 (0.630551% change)
#     iteration    8: trace = 0.6252943667532129 (0.132056% change)
#     iteration    9: trace = 0.6250948741056406 (0.0319089% change)
#     iteration   10: trace = 0.6250605519627868 (0.00549086% change)
#     iteration   11: trace = 0.625052450912134 (0.00129605% change)
#     iteration   12: trace = 0.6250503736085129 (0.000332341% change)
#     iteration   13: trace = 0.6250499861933153 (6.19815e-05% change)
#     iteration   14: trace = 0.6250498941484 (1.4726e-05% change)
#     iteration   15: trace = 0.625049877303391 (2.69499e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.354681, 0.38339, 0.413051, 0.426207
# elapsed time for k point: 2.9184300899505615
# total elapsed time for run: 3.0064518451690674
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.390071,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.195035..0.195035, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.390071,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10682082176208496
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.779591433889312 (188.871% change)
#     iteration    2: trace = 1.318296472917424 (142.039% change)
#     iteration    3: trace = 0.9923305083859708 (28.2145% change)
#     iteration    4: trace = 0.8914293900988393 (10.7127% change)
#     iteration    5: trace = 0.8561191268858498 (4.04112% change)
#     iteration    6: trace = 0.8322090521168106 (2.8324% change)
#     iteration    7: trace = 0.8132735405155134 (2.30151% change)
#     iteration    8: trace = 0.804189701680542 (1.12322% change)
#     iteration    9: trace = 0.799574484485012 (0.575548% change)
#     iteration   10: trace = 0.7980689742317125 (0.188466% change)
#     iteration   11: trace = 0.7975660579792677 (0.0630365% change)
#     iteration   12: trace = 0.7974229156263344 (0.017949% change)
#     iteration   13: trace = 0.7973808047331503 (0.00528101% change)
#     iteration   14: trace = 0.7973677012700826 (0.00164333% change)
#     iteration   15: trace = 0.7973641102860858 (0.000450356% change)
#     iteration   16: trace = 0.7973630155958104 (0.000137289% change)
#     iteration   17: trace = 0.79736273493542 (3.51986e-05% change)
#     iteration   18: trace = 0.79736266022864 (9.36923e-06% change)
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.427819, 0.431523, 0.461603, 0.463729
# elapsed time for k point: 3.4483330249786377
# total elapsed time for run: 3.555211067199707
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.425532,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08757710456848145
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.341514154744669 (189.469% change)
#     iteration    2: trace = 1.073567057159454 (148.969% change)
#     iteration    3: trace = 0.7798031022354838 (31.7005% change)
#     iteration    4: trace = 0.6825789432175172 (13.2967% change)
#     iteration    5: trace = 0.6461102894706783 (5.48942% change)
#     iteration    6: trace = 0.6335046115761173 (1.97023% change)
#     iteration    7: trace = 0.6301645162316321 (0.528634% change)
#     iteration    8: trace = 0.6294390325760647 (0.115192% change)
#     iteration    9: trace = 0.6292549766529489 (0.0292455% change)
#     iteration   10: trace = 0.6292193735992587 (0.00565813% change)
#     iteration   11: trace = 0.6292099558804649 (0.00149674% change)
#     iteration   12: trace = 0.6292079209694128 (0.000323408% change)
#     iteration   13: trace = 0.629207542150142 (6.02058e-05% change)
#     iteration   14: trace = 0.6292074704215296 (1.13998e-05% change)
#     iteration   15: trace = 0.6292074567158477 (2.17825e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.355457, 0.386379, 0.413794, 0.427017
# elapsed time for k point: 2.9240379333496094
# total elapsed time for run: 3.0116820335388184
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.425532,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.212766..0.212766, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.425532,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08608102798461914
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 8.001751024705401 (188.565% change)
#     iteration    2: trace = 1.294392438183761 (144.304% change)
#     iteration    3: trace = 0.9841438287215506 (27.2323% change)
#     iteration    4: trace = 0.8820622241467471 (10.94% change)
#     iteration    5: trace = 0.8385368143810639 (5.05933% change)
#     iteration    6: trace = 0.8149438555320623 (2.85373% change)
#     iteration    7: trace = 0.8045709732543873 (1.28099% change)
#     iteration    8: trace = 0.8010103275378024 (0.443534% change)
#     iteration    9: trace = 0.7995717794322272 (0.179753% change)
#     iteration   10: trace = 0.7991398869022187 (0.0540301% change)
#     iteration   11: trace = 0.7990060531690668 (0.0167486% change)
#     iteration   12: trace = 0.7989693546419925 (0.00459313% change)
#     iteration   13: trace = 0.7989593482579334 (0.00125242% change)
#     iteration   14: trace = 0.7989560702700751 (0.000410283% change)
#     iteration   15: trace = 0.7989551152997281 (0.000119527% change)
#     iteration   16: trace = 0.798954810059473 (3.82049e-05% change)
#     iteration   17: trace = 0.7989547319252884 (9.77955e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.428322, 0.432435, 0.461769, 0.463966
# elapsed time for k point: 3.2903292179107666
# total elapsed time for run: 3.3764679431915283
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.460993,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1264171600341797
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.976744335021842 (188.585% change)
#     iteration    2: trace = 1.172332107299326 (148.745% change)
#     iteration    3: trace = 0.8144185486362158 (36.03% change)
#     iteration    4: trace = 0.6870562884203671 (16.965% change)
#     iteration    5: trace = 0.6488315255965366 (5.72275% change)
#     iteration    6: trace = 0.6369695030780549 (1.84508% change)
#     iteration    7: trace = 0.6339503050874222 (0.47512% change)
#     iteration    8: trace = 0.6333771983466532 (0.0904434% change)
#     iteration    9: trace = 0.6332527390281393 (0.019652% change)
#     iteration   10: trace = 0.6332346132497018 (0.00286237% change)
#     iteration   11: trace = 0.6332311641963339 (0.000544674% change)
#     iteration   12: trace = 0.6332305593517042 (9.55172e-05% change)
#     iteration   13: trace = 0.6332304350955302 (1.96226e-05% change)
#     iteration   14: trace = 0.6332304066961683 (4.48484e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.356335, 0.389089, 0.414646, 0.427708
# elapsed time for k point: 2.728490114212036
# total elapsed time for run: 2.854966640472412
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.460993,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.230496..0.230496, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.460993,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08878493309020996
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.885126950566044 (188.729% change)
#     iteration    2: trace = 1.28999872981364 (143.761% change)
#     iteration    3: trace = 0.9756670854167221 (27.7474% change)
#     iteration    4: trace = 0.8803379654650362 (10.2725% change)
#     iteration    5: trace = 0.8439247279301503 (4.22363% change)
#     iteration    6: trace = 0.8218444016808247 (2.65107% change)
#     iteration    7: trace = 0.8093398226409672 (1.53319% change)
#     iteration    8: trace = 0.8041307530215136 (0.645698% change)
#     iteration    9: trace = 0.8016483656237889 (0.309182% change)
#     iteration   10: trace = 0.8007595189828541 (0.110939% change)
#     iteration   11: trace = 0.8004695199703147 (0.0362221% change)
#     iteration   12: trace = 0.8003945134700996 (0.00937075% change)
#     iteration   13: trace = 0.8003748221059552 (0.00246024% change)
#     iteration   14: trace = 0.8003688094825803 (0.000751229% change)
#     iteration   15: trace = 0.8003671239199162 (0.000210598% change)
#     iteration   16: trace = 0.8003665876760139 (6.69998e-05% change)
#     iteration   17: trace = 0.8003664507489082 (1.71081e-05% change)
#     iteration   18: trace = 0.8003664154868326 (4.40574e-06% change)
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.428773, 0.433265, 0.461907, 0.464158
# elapsed time for k point: 3.4567911624908447
# total elapsed time for run: 3.545639991760254
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.496454,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09482312202453613
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.41460226262277 (189.361% change)
#     iteration    2: trace = 1.151913498551236 (146.213% change)
#     iteration    3: trace = 0.8132629770529052 (34.4652% change)
#     iteration    4: trace = 0.7464824388600007 (8.563% change)
#     iteration    5: trace = 0.7234964244935018 (3.12739% change)
#     iteration    6: trace = 0.6936503849580843 (4.21213% change)
#     iteration    7: trace = 0.665660060655787 (4.11831% change)
#     iteration    8: trace = 0.6473393277918582 (2.79067% change)
#     iteration    9: trace = 0.6394675170085046 (1.22346% change)
#     iteration   10: trace = 0.6375715395442774 (0.296933% change)
#     iteration   11: trace = 0.6371243522075765 (0.0701638% change)
#     iteration   12: trace = 0.6370353398081774 (0.0139719% change)
#     iteration   13: trace = 0.6370145510280909 (0.00326342% change)
#     iteration   14: trace = 0.6370098947166144 (0.000730961% change)
#     iteration   15: trace = 0.6370088695047224 (0.000160941% change)
#     iteration   16: trace = 0.6370086304731751 (3.75241e-05% change)
#     iteration   17: trace = 0.6370085860432779 (6.97477e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.357371, 0.39139, 0.415507, 0.428325
# elapsed time for k point: 3.2641592025756836
# total elapsed time for run: 3.3590400218963623
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.496454,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.248227..0.248227, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.496454,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1286170482635498
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.493329383456522 (189.273% change)
#     iteration    2: trace = 1.249496764281989 (142.833% change)
#     iteration    3: trace = 0.9720866471722159 (24.9741% change)
#     iteration    4: trace = 0.8866725524610557 (9.19044% change)
#     iteration    5: trace = 0.8507073067905212 (4.14017% change)
#     iteration    6: trace = 0.8280914756491765 (2.69429% change)
#     iteration    7: trace = 0.8139925244082022 (1.7172% change)
#     iteration    8: trace = 0.8071839207275907 (0.839958% change)
#     iteration    9: trace = 0.8035969678091831 (0.445368% change)
#     iteration   10: trace = 0.8022632479285741 (0.166107% change)
#     iteration   11: trace = 0.8018058872644653 (0.0570251% change)
#     iteration   12: trace = 0.8016840142258789 (0.015201% change)
#     iteration   13: trace = 0.8016535735117893 (0.00379717% change)
#     iteration   14: trace = 0.8016450195521706 (0.00106705% change)
#     iteration   15: trace = 0.801642506558128 (0.00031348% change)
#     iteration   16: trace = 0.801641671496365 (0.000104169% change)
#     iteration   17: trace = 0.8016414482584113 (2.78476e-05% change)
#     iteration   18: trace = 0.8016413853050499 (7.85306e-06% change)
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.429189, 0.434005, 0.462048, 0.464316
# elapsed time for k point: 3.441106081008911
# total elapsed time for run: 3.5697898864746094
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
# ...
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.602837,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.08987307548522949
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.797393083434731 (188.84% change)
#     iteration    2: trace = 1.219500260597827 (145.902% change)
#     iteration    3: trace = 0.887764360751442 (31.485% change)
#     iteration    4: trace = 0.7708151491308818 (14.1023% change)
#     iteration    5: trace = 0.7289541337750061 (5.58233% change)
#     iteration    6: trace = 0.7083353142144552 (2.86913% change)
#     iteration    7: trace = 0.6790898370341746 (4.21579% change)
#     iteration    8: trace = 0.6585038832056258 (3.07806% change)
#     iteration    9: trace = 0.6513974991150316 (1.08503% change)
#     iteration   10: trace = 0.6493192689482242 (0.319552% change)
#     iteration   11: trace = 0.6488931828285193 (0.065642% change)
#     iteration   12: trace = 0.6487809764663812 (0.0172935% change)
#     iteration   13: trace = 0.6487557449650723 (0.00388914% change)
#     iteration   14: trace = 0.6487497390700573 (0.00092576% change)
#     iteration   15: trace = 0.6487485667408422 (0.000180706% change)
#     iteration   16: trace = 0.6487483205768194 (3.79444e-05% change)
#     iteration   17: trace = 0.6487482910364754 (4.55344e-06% change)
# Finished solving for bands 1 to 4 after 17 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.361611, 0.397889, 0.418164, 0.429893
# elapsed time for k point: 3.2855539321899414
# total elapsed time for run: 3.3755128383636475
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.602837,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.301418..0.301418, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.602837,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09011411666870117
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 8.091432517741822 (188.44% change)
#     iteration    2: trace = 1.344262569760485 (143.014% change)
#     iteration    3: trace = 1.029326235605545 (26.5367% change)
#     iteration    4: trace = 0.9170664826988069 (11.5352% change)
#     iteration    5: trace = 0.8668803369510572 (5.62642% change)
#     iteration    6: trace = 0.8345214573400266 (3.80379% change)
#     iteration    7: trace = 0.8161770481156405 (2.22262% change)
#     iteration    8: trace = 0.8097304102359529 (0.79299% change)
#     iteration    9: trace = 0.806932153382995 (0.346177% change)
#     iteration   10: trace = 0.8060081191993878 (0.114578% change)
#     iteration   11: trace = 0.805673889320963 (0.0414759% change)
#     iteration   12: trace = 0.8055644603187018 (0.0135832% change)
#     iteration   13: trace = 0.8055347894851045 (0.0036833% change)
#     iteration   14: trace = 0.8055266569596022 (0.00100959% change)
#     iteration   15: trace = 0.805524596655035 (0.000255771% change)
#     iteration   16: trace = 0.8055239779594132 (7.68066e-05% change)
#     iteration   17: trace = 0.8055237960065448 (2.25881e-05% change)
#     iteration   18: trace = 0.8055237444821511 (6.39638e-06% change)
# Finished solving for bands 1 to 4 after 18 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.43059, 0.436069, 0.462579, 0.464737
# elapsed time for k point: 3.496938705444336
# total elapsed time for run: 3.5871193408966064
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.638298,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09199905395507812
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.786158201084396 (188.86% change)
#     iteration    2: trace = 1.186556974447333 (147.104% change)
#     iteration    3: trace = 0.8437002360626525 (33.7747% change)
#     iteration    4: trace = 0.7276695509862163 (14.7681% change)
#     iteration    5: trace = 0.6754433686117958 (7.44433% change)
#     iteration    6: trace = 0.6581802863748887 (2.5889% change)
#     iteration    7: trace = 0.6541356707053377 (0.616409% change)
#     iteration    8: trace = 0.653396622450771 (0.113045% change)
#     iteration    9: trace = 0.6532363704574494 (0.024529% change)
#     iteration   10: trace = 0.6532128501140393 (0.00360065% change)
#     iteration   11: trace = 0.6532081742237992 (0.000715832% change)
#     iteration   12: trace = 0.6532073393494366 (0.000127811% change)
#     iteration   13: trace = 0.6532071719243795 (2.56312e-05% change)
#     iteration   14: trace = 0.6532071397321078 (4.92834e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.363615, 0.399886, 0.419279, 0.43045
# elapsed time for k point: 2.726038694381714
# total elapsed time for run: 2.818093776702881
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 175 x 90.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 10.6383, 0)
#      (0, 0, 5.31915)
# Cell volume = 56.5867
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.094, -0)
#      (0, -0, 0.188)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.12766,0.531915)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.638298,0.531915,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.37994..5.37994, -2.71868..2.71868)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, -5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.319149..0.319149, -0.265957..0.265957, -5e+19..5e+19)
#           shift object by (0, 0, 5.31915)
#           ellipsoid, center = (0,0,0)
#                size (0.638298,0.531915,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.06383..1.06383, -0.265957..0.265957)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.12766,0.531915)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.09090685844421387
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.6028189652873 (189.12% change)
#     iteration    2: trace = 1.233973952932875 (144.144% change)
#     iteration    3: trace = 0.9454631865643155 (26.4757% change)
#     iteration    4: trace = 0.8788485296417901 (7.30299% change)
#     iteration    5: trace = 0.8557367371786134 (2.66482% change)
#     iteration    6: trace = 0.8395970530303551 (1.90401% change)
#     iteration    7: trace = 0.8258458391180519 (1.65136% change)
#     iteration    8: trace = 0.8166298944930538 (1.1222% change)
#     iteration    9: trace = 0.8107678110175918 (0.720424% change)
#     iteration   10: trace = 0.8083404608850653 (0.299838% change)
#     iteration   11: trace = 0.8074918952432688 (0.105031% change)
#     iteration   12: trace = 0.8072408154598827 (0.0310986% change)
#     iteration   13: trace = 0.8071729300229481 (0.00840992% change)
#     iteration   14: trace = 0.8071510402092013 (0.00271195% change)
#     iteration   15: trace = 0.8071447580567762 (0.000778315% change)
#     iteration   16: trace = 0.8071425982821747 (0.000267582% change)
#     iteration   17: trace = 0.8071420124892146 (7.25762e-05% change)
#     iteration   18: trace = 0.807141834954217 (2.19955e-05% change)
#     iteration   19: trace = 0.807141778740693 (6.96452e-06% change)
# Finished solving for bands 1 to 4 after 19 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.43129, 0.436756, 0.462849, 0.464915
# elapsed time for k point: 3.6288251876831055
# total elapsed time for run: 3.7197911739349365
# done

# %% [markdown]
# ### 7.2 — Plot the sweep

# %%
fig, ax = sim.plot_sweep(
    units='THz',
    freq0_Hz=f_target,  # optional target frequency line
)

# %% [markdown]
# ### 7.3 — Access raw sweep data

# %%
sd = sim.sweep_data

print("Keys:", list(sd.keys()))
print("Shape of TE freqs:", sd['zeven_freqs'].shape)  # (n_param_values, num_bands)
print("Band 0 TE-like freqs (c/a):", sd['zeven_freqs'][:, 0])
# Out:
# Keys: ['param_name', 'param_values_um', 'kx', 'zeven_freqs', 'zodd_freqs', 'Lx_per_point']
# Shape of TE freqs: (10, 4)
# Band 0 TE-like freqs (c/a): [0.35345811 0.35398559 0.3546815  0.35545681 0.35633532 0.35737128
#  0.35863452 0.36006045 0.36161147 0.36361517]

# %% [markdown]
# ## 8 — Multi-Parameter Sweeps (N-D)
#
# Sweep over a grid of two or more parameters simultaneously.

# %% [markdown]
# ### 8.1 — Run a 2-D sweep

# %%
multisweep = sim.run_multisweep(
    param_ranges={
        'Lx': np.linspace(0.40, 0.60, 6),  # lattice constant (µm)
        'p1': np.linspace(0.150, 0.30, 6),  # hole diameter (µm)
    },
    kx=0.5,
)
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.375,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.11543393135070801
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.682842399679749 (188.376% change)
#     iteration    2: trace = 1.126501062335346 (148.85% change)
#     iteration    3: trace = 0.771533165036255 (37.4037% change)
#     iteration    4: trace = 0.6702574014732955 (14.0486% change)
#     iteration    5: trace = 0.6180690346974338 (8.10173% change)
#     iteration    6: trace = 0.5751968593343395 (7.18569% change)
#     iteration    7: trace = 0.5566585456656989 (3.27574% change)
#     iteration    8: trace = 0.5521301303432929 (0.816822% change)
#     iteration    9: trace = 0.5507779903685879 (0.245195% change)
#     iteration   10: trace = 0.5503722987187358 (0.0736851% change)
#     iteration   11: trace = 0.5502863230208316 (0.0156226% change)
#     iteration   12: trace = 0.5502724647509525 (0.00251841% change)
#     iteration   13: trace = 0.5502697926947437 (0.000485589% change)
#     iteration   14: trace = 0.5502692907105304 (9.12251e-05% change)
#     iteration   15: trace = 0.5502691587681496 (2.39778e-05% change)
#     iteration   16: trace = 0.5502691384540428 (3.69167e-06% change)
# Finished solving for bands 1 to 4 after 16 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.337956, 0.364307, 0.384182, 0.394639
# elapsed time for k point: 3.4771790504455566
# total elapsed time for run: 3.5926971435546875
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.375,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.1875..0.1875, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.375,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.11006402969360352
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.597060855316564 (188.509% change)
#     iteration    2: trace = 1.220781559777744 (144.622% change)
#     iteration    3: trace = 0.881898614344771 (32.2334% change)
#     iteration    4: trace = 0.7726563267814095 (13.205% change)
#     iteration    5: trace = 0.7212706094008017 (6.87928% change)
#     iteration    6: trace = 0.7045592639895895 (2.34409% change)
#     iteration    7: trace = 0.7004111595449402 (0.59049% change)
#     iteration    8: trace = 0.6996363972628117 (0.110677% change)
#     iteration    9: trace = 0.6995041789528904 (0.0188999% change)
#     iteration   10: trace = 0.6994743593097761 (0.00426306% change)
#     iteration   11: trace = 0.6994691255061936 (0.000748251% change)
#     iteration   12: trace = 0.6994679824839725 (0.000163413% change)
#     iteration   13: trace = 0.6994677129097099 (3.85399e-05% change)
#     iteration   14: trace = 0.6994676495863429 (9.05308e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.404386, 0.407901, 0.428884, 0.43083
# elapsed time for k point: 3.073113203048706
# total elapsed time for run: 3.1832339763641357
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.45,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1080019474029541
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.599459343785325 (188.495% change)
#     iteration    2: trace = 1.114918039383622 (148.824% change)
#     iteration    3: trace = 0.7175931662884634 (43.364% change)
#     iteration    4: trace = 0.5953425839418723 (18.6225% change)
#     iteration    5: trace = 0.5652158282583796 (5.19177% change)
#     iteration    6: trace = 0.559399533258038 (1.03436% change)
#     iteration    7: trace = 0.5578614466188397 (0.275332% change)
#     iteration    8: trace = 0.5574487231584568 (0.0740105% change)
#     iteration    9: trace = 0.5573521905822795 (0.0173184% change)
#     iteration   10: trace = 0.5573338620085426 (0.00328856% change)
#     iteration   11: trace = 0.5573307916295462 (0.000550906% change)
#     iteration   12: trace = 0.5573299962275132 (0.000142716% change)
#     iteration   13: trace = 0.5573298131621763 (3.28469e-05% change)
#     iteration   14: trace = 0.5573297699437925 (7.75454e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.3396, 0.369468, 0.385614, 0.395976
# elapsed time for k point: 3.0752499103546143
# total elapsed time for run: 3.183302164077759
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.45,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.225..0.225, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.45,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10661101341247559
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.476596225107244 (188.689% change)
#     iteration    2: trace = 1.211878979496602 (144.208% change)
#     iteration    3: trace = 0.8947132055424677 (30.1117% change)
#     iteration    4: trace = 0.8087149951732902 (10.0971% change)
#     iteration    5: trace = 0.7753239261915071 (4.21594% change)
#     iteration    6: trace = 0.7402404027146456 (4.62976% change)
#     iteration    7: trace = 0.7151978754169999 (3.44124% change)
#     iteration    8: trace = 0.7054824139666391 (1.36772% change)
#     iteration    9: trace = 0.7032049315502915 (0.323348% change)
#     iteration   10: trace = 0.702667713010526 (0.0764249% change)
#     iteration   11: trace = 0.7025717160162193 (0.0136627% change)
#     iteration   12: trace = 0.7025511330945373 (0.0029297% change)
#     iteration   13: trace = 0.7025459533979215 (0.000737272% change)
#     iteration   14: trace = 0.70254481710183 (0.00016174% change)
#     iteration   15: trace = 0.7025445279652147 (4.11556e-05% change)
#     iteration   16: trace = 0.7025444595280741 (9.74132e-06% change)
# Finished solving for bands 1 to 4 after 16 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.405461, 0.409812, 0.429205, 0.431258
# elapsed time for k point: 3.5208046436309814
# total elapsed time for run: 3.6274709701538086
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.525,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10851907730102539
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.565662038476585 (188.541% change)
#     iteration    2: trace = 1.148593969413272 (147.277% change)
#     iteration    3: trace = 0.7852402795889435 (37.5786% change)
#     iteration    4: trace = 0.6772217697199534 (14.7721% change)
#     iteration    5: trace = 0.6237375077706995 (8.22228% change)
#     iteration    6: trace = 0.5896225459021084 (5.62322% change)
#     iteration    7: trace = 0.5728141854255508 (2.89192% change)
#     iteration    8: trace = 0.5668721700768568 (1.04275% change)
#     iteration    9: trace = 0.5649706735952599 (0.336% change)
#     iteration   10: trace = 0.5644281138145666 (0.0960794% change)
#     iteration   11: trace = 0.5643254959004713 (0.0181825% change)
#     iteration   12: trace = 0.5643078817886179 (0.00312132% change)
#     iteration   13: trace = 0.5643049443566336 (0.000520538% change)
#     iteration   14: trace = 0.5643044046518442 (9.56407e-05% change)
#     iteration   15: trace = 0.5643042729222568 (2.33437e-05% change)
#     iteration   16: trace = 0.5643042493271837 (4.18127e-06% change)
# Finished solving for bands 1 to 4 after 16 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.342033, 0.373721, 0.387257, 0.397092
# elapsed time for k point: 3.54085111618042
# total elapsed time for run: 3.649427890777588
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.525,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.2625..0.2625, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.525,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1059420108795166
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.808811687367458 (188.198% change)
#     iteration    2: trace = 1.276613412959321 (143.795% change)
#     iteration    3: trace = 0.9102046368995518 (33.5107% change)
#     iteration    4: trace = 0.7728592748930879 (16.3209% change)
#     iteration    5: trace = 0.7209605141898321 (6.94846% change)
#     iteration    6: trace = 0.7088531029213179 (1.69356% change)
#     iteration    7: trace = 0.7060610807922828 (0.394656% change)
#     iteration    8: trace = 0.7055458247667922 (0.0730028% change)
#     iteration    9: trace = 0.7054483861073086 (0.0138113% change)
#     iteration   10: trace = 0.7054255121911513 (0.00324252% change)
#     iteration   11: trace = 0.7054211082008192 (0.000624305% change)
#     iteration   12: trace = 0.705420090556041 (0.000144261% change)
#     iteration   13: trace = 0.7054198344655611 (3.63033e-05% change)
#     iteration   14: trace = 0.7054197781405662 (7.98461e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.406562, 0.411467, 0.429572, 0.431614
# elapsed time for k point: 3.1086959838867188
# total elapsed time for run: 3.214735984802246
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.6,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10682797431945801
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.608438037230917 (188.482% change)
#     iteration    2: trace = 1.156264271356849 (147.231% change)
#     iteration    3: trace = 0.7663772200605491 (40.5574% change)
#     iteration    4: trace = 0.6540292980108635 (15.8191% change)
#     iteration    5: trace = 0.5971657447779481 (9.08948% change)
#     iteration    6: trace = 0.5771436017143141 (3.41003% change)
#     iteration    7: trace = 0.5723646592571712 (0.831476% change)
#     iteration    8: trace = 0.5713488771443729 (0.177629% change)
#     iteration    9: trace = 0.5711170373285167 (0.0405859% change)
#     iteration   10: trace = 0.5710568369483587 (0.0105414% change)
#     iteration   11: trace = 0.5710454312375473 (0.00199732% change)
#     iteration   12: trace = 0.5710427695343303 (0.000466112% change)
#     iteration   13: trace = 0.5710422786587369 (8.59613e-05% change)
#     iteration   14: trace = 0.5710421683265225 (1.93212e-05% change)
#     iteration   15: trace = 0.5710421450139304 (4.08246e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.345073, 0.377254, 0.388893, 0.398006
# elapsed time for k point: 3.3562850952148438
# total elapsed time for run: 3.4631800651550293
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.6,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3..0.3, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.6,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.14891910552978516
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.675432418921366 (188.406% change)
#     iteration    2: trace = 1.25143365664801 (143.925% change)
#     iteration    3: trace = 0.9338740409575547 (29.0631% change)
#     iteration    4: trace = 0.8264072080183192 (12.2102% change)
#     iteration    5: trace = 0.7584088426378707 (8.58123% change)
#     iteration    6: trace = 0.7225725275175774 (4.83954% change)
#     iteration    7: trace = 0.7114244249231112 (1.55483% change)
#     iteration    8: trace = 0.7086946634235238 (0.384441% change)
#     iteration    9: trace = 0.7081865317051931 (0.0717254% change)
#     iteration   10: trace = 0.7080755635509761 (0.0156706% change)
#     iteration   11: trace = 0.7080569804178366 (0.00262449% change)
#     iteration   12: trace = 0.7080529167123978 (0.000573925% change)
#     iteration   13: trace = 0.7080520688577667 (0.000119745% change)
#     iteration   14: trace = 0.7080518779452903 (2.69631e-05% change)
#     iteration   15: trace = 0.7080518293629682 (6.86141e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.407621, 0.412919, 0.429942, 0.431908
# elapsed time for k point: 3.3189711570739746
# total elapsed time for run: 3.4679510593414307
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.675,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10934281349182129
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.316831882104093 (188.913% change)
#     iteration    2: trace = 1.154165975760923 (145.5% change)
#     iteration    3: trace = 0.8272401098468916 (32.9994% change)
#     iteration    4: trace = 0.6835240926197813 (19.0256% change)
#     iteration    5: trace = 0.6136118800330423 (10.7795% change)
#     iteration    6: trace = 0.587896292579193 (4.28055% change)
#     iteration    7: trace = 0.5804386183128502 (1.27663% change)
#     iteration    8: trace = 0.5787268415416631 (0.295346% change)
#     iteration    9: trace = 0.5782683173370309 (0.0792612% change)
#     iteration   10: trace = 0.5781357815633517 (0.0229221% change)
#     iteration   11: trace = 0.5781086277043742 (0.00469691% change)
#     iteration   12: trace = 0.5781038894323463 (0.00081962% change)
#     iteration   13: trace = 0.5781031936447197 (0.000120357% change)
#     iteration   14: trace = 0.5781030728206771 (2.09001e-05% change)
#     iteration   15: trace = 0.5781030513517158 (3.71369e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.349155, 0.380179, 0.390642, 0.39882
# elapsed time for k point: 3.3190081119537354
# total elapsed time for run: 3.4284238815307617
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.675,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.3375..0.3375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.675,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.11347293853759766
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.670057896668683 (188.407% change)
#     iteration    2: trace = 1.249103665498089 (143.981% change)
#     iteration    3: trace = 0.8934824713029743 (33.1955% change)
#     iteration    4: trace = 0.7872873174020378 (12.6365% change)
#     iteration    5: trace = 0.737802181975815 (6.48947% change)
#     iteration    6: trace = 0.7180083188059176 (2.71929% change)
#     iteration    7: trace = 0.7123439732447843 (0.792021% change)
#     iteration    8: trace = 0.7110760051517736 (0.178158% change)
#     iteration    9: trace = 0.7108449255745711 (0.0325025% change)
#     iteration   10: trace = 0.7107866131711047 (0.00820359% change)
#     iteration   11: trace = 0.7107761991849123 (0.00146515% change)
#     iteration   12: trace = 0.7107739258930672 (0.000319833% change)
#     iteration   13: trace = 0.7107734602273719 (6.55153e-05% change)
#     iteration   14: trace = 0.7107733597435707 (1.41372e-05% change)
#     iteration   15: trace = 0.7107733335015037 (3.69204e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.408886, 0.41418, 0.430402, 0.432197
# elapsed time for k point: 3.290708065032959
# total elapsed time for run: 3.4042389392852783
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.75,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.14627695083618164
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.457519713340404 (188.721% change)
#     iteration    2: trace = 1.204868503325871 (144.363% change)
#     iteration    3: trace = 0.8075246902301267 (39.4897% change)
#     iteration    4: trace = 0.6402258660391984 (23.1116% change)
#     iteration    5: trace = 0.5971017538207319 (6.97052% change)
#     iteration    6: trace = 0.5883994800843095 (1.46812% change)
#     iteration    7: trace = 0.5858705091215403 (0.430731% change)
#     iteration    8: trace = 0.5852996173748115 (0.0974908% change)
#     iteration    9: trace = 0.5851658446234533 (0.022858% change)
#     iteration   10: trace = 0.5851349503883614 (0.00527971% change)
#     iteration   11: trace = 0.5851298481990082 (0.000871972% change)
#     iteration   12: trace = 0.5851288939309223 (0.000163087% change)
#     iteration   13: trace = 0.5851287122582485 (3.10483e-05% change)
#     iteration   14: trace = 0.5851286766251993 (6.08978e-06% change)
# Finished solving for bands 1 to 4 after 14 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.354071, 0.382393, 0.392361, 0.399488
# elapsed time for k point: 3.077848196029663
# total elapsed time for run: 3.2241780757904053
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 200 x 100.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 12.5, 0)
#      (0, 0, 6.25)
# Cell volume = 78.125
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.08, -0)
#      (0, -0, 0.16)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.5,0.625)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.75,0.625,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -6.3125..6.3125, -3.1875..3.1875)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, -6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.375..0.375, -0.3125..0.3125, -5e+19..5e+19)
#           shift object by (0, 0, 6.25)
#           ellipsoid, center = (0,0,0)
#                size (0.75,0.625,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.25..1.25, -0.3125..0.3125)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.5,0.625)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1075279712677002
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.67167530588745 (188.413% change)
#     iteration    2: trace = 1.234155219435106 (144.569% change)
#     iteration    3: trace = 0.8916046759061687 (32.2285% change)
#     iteration    4: trace = 0.8029150108205249 (10.4678% change)
#     iteration    5: trace = 0.7575535374936526 (5.81383% change)
#     iteration    6: trace = 0.728485607485762 (3.91214% change)
#     iteration    7: trace = 0.7169281051163314 (1.5992% change)
#     iteration    8: trace = 0.7138882285853381 (0.424915% change)
#     iteration    9: trace = 0.7133670080176681 (0.0730382% change)
#     iteration   10: trace = 0.7132366833589868 (0.0182706% change)
#     iteration   11: trace = 0.7132147709876224 (0.00307229% change)
#     iteration   12: trace = 0.7132105109263198 (0.000597306% change)
#     iteration   13: trace = 0.7132096543190829 (0.000120106% change)
#     iteration   14: trace = 0.7132094997297904 (2.16752e-05% change)
#     iteration   15: trace = 0.7132094672055211 (4.56027e-06% change)
# Finished solving for bands 1 to 4 after 15 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.41011, 0.415214, 0.430834, 0.432433
# elapsed time for k point: 3.2866580486297607
# total elapsed time for run: 3.394258975982666
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 189 x 96.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 11.3636, 0)
#      (0, 0, 5.68182)
# Cell volume = 64.5661
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.088, -0)
#      (0, -0, 0.176)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,2.27273,0.568182)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.340909,0.568182,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -5.74194..5.74194, -2.90009..2.90009)
#           bounding box (-0.170455..0.170455, -0.284091..0.284091, -5e+19..5e+19)
#           shift object by (0, 0, -5.68182)
#           ellipsoid, center = (0,0,0)
#                size (0.340909,0.568182,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.170455..0.170455, -0.284091..0.284091, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.340909,0.568182,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.170455..0.170455, -0.284091..0.284091, -5e+19..5e+19)
#           shift object by (0, 0, 5.68182)
#           ellipsoid, center = (0,0,0)
#                size (0.340909,0.568182,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.13636..1.13636, -0.284091..0.284091)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.27273,0.568182)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.13636..1.13636, -0.284091..0.284091)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.27273,0.568182)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -1.13636..1.13636, -0.284091..0.284091)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,2.27273,0.568182)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.10048174858093262
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.809450152727655 (188.882% change)
#     iteration    2: trace = 1.134849712965552 (149.248% change)
#     iteration    3: trace = 0.7595041624485812 (39.6278% change)
#     iteration    4: trace = 0.6511214984057998 (15.3666% change)
#     iteration    5: trace = 0.6075495051767608 (6.92349% change)
#     iteration    6: trace = 0.5933820709154652 (2.35941% change)
# ...
#     iteration   42: trace = 0.937656139528525 (0.000116802% change)
#     iteration   43: trace = 0.9376553501472603 (8.41867e-05% change)
#     iteration   44: trace = 0.9376547254224641 (6.66263e-05% change)
#     iteration   45: trace = 0.9376538430074637 (9.41088e-05% change)
#     iteration   46: trace = 0.937652312445536 (0.000163233% change)
#     iteration   47: trace = 0.937650381158069 (0.000205971% change)
#     iteration   48: trace = 0.9376479021779059 (0.000264382% change)
#     iteration   49: trace = 0.9376440313947348 (0.000412819% change)
#     iteration   50: trace = 0.9376383157770876 (0.000609574% change)
#     iteration   51: trace = 0.9376307535344917 (0.000806523% change)
#     iteration   52: trace = 0.937624692613269 (0.00064641% change)
#     iteration   53: trace = 0.9376214057225152 (0.000350556% change)
#     iteration   54: trace = 0.937619975492277 (0.000152538% change)
#     iteration   55: trace = 0.9376193327487852 (6.85506e-05% change)
#     iteration   56: trace = 0.9376189329794317 (4.26366e-05% change)
#     iteration   57: trace = 0.9376186543244718 (2.97194e-05% change)
#     iteration   58: trace = 0.9376184528302841 (2.149e-05% change)
#     iteration   59: trace = 0.9376183024904333 (1.60342e-05% change)
#     iteration   60: trace = 0.9376181564940895 (1.5571e-05% change)
#     iteration   61: trace = 0.93761798635913 (1.81454e-05% change)
#     iteration   62: trace = 0.9376177310945457 (2.72248e-05% change)
#     large trace change predicted (5.66624e-05%)
#     iteration   63: trace = 0.9376171980251194 (5.68536e-05% change)
#     iteration   64: trace = 0.9376163284692649 (9.27411e-05% change)
#     iteration   65: trace = 0.9376154366456808 (9.51161e-05% change)
#     iteration   66: trace = 0.9376148562197575 (6.19045e-05% change)
#     iteration   67: trace = 0.9376145185903459 (3.60094e-05% change)
#     iteration   68: trace = 0.9376142809653338 (2.53436e-05% change)
#     iteration   69: trace = 0.9376141115164669 (1.80723e-05% change)
#     resetting CG direction...
#     iteration   70: trace = 0.9376140439642562 (7.20469e-06% change)
# Finished solving for bands 1 to 4 after 70 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.461183, 0.465013, 0.504047, 0.504603
# elapsed time for k point: 8.099292755126953
# total elapsed time for run: 8.159127950668335
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 135 x 70.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 8.33333, 0)
#      (0, 0, 4.16667)
# Cell volume = 34.7222
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.12, -0)
#      (0, -0, 0.24)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.66667,0.416667)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.5,0.416667,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -4.2284..4.2284, -2.14286..2.14286)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, -4.16667)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, 4.16667)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.07106590270996094
# solve_kpoint (0.5,0,0):
# zevenfreqs:, k index, k1, k2, k3, kmag/2pi, zeven band 1, zeven band 2, zeven band 3, zeven band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 7.709515019444419 (188.8% change)
#     iteration    2: trace = 1.194267651565183 (146.348% change)
#     iteration    3: trace = 0.9075071018728202 (27.2875% change)
#     iteration    4: trace = 0.8349754985197235 (8.32509% change)
#     iteration    5: trace = 0.8134198800518596 (2.61535% change)
#     iteration    6: trace = 0.8029265735137144 (1.2984% change)
#     iteration    7: trace = 0.7971308928254413 (0.724434% change)
#     iteration    8: trace = 0.7926865066168841 (0.559106% change)
#     iteration    9: trace = 0.7868767953719635 (0.73561% change)
#     iteration   10: trace = 0.7821432071739914 (0.603381% change)
#     iteration   11: trace = 0.7794195355747897 (0.348839% change)
#     iteration   12: trace = 0.7779220969592721 (0.192307% change)
#     iteration   13: trace = 0.7773695054819711 (0.0710595% change)
#     iteration   14: trace = 0.7771493459226165 (0.0283251% change)
#     iteration   15: trace = 0.7770753977155482 (0.00951577% change)
#     iteration   16: trace = 0.7770517833845938 (0.00303892% change)
#     iteration   17: trace = 0.7770461975408471 (0.000718853% change)
#     iteration   18: trace = 0.7770447674452462 (0.000184043% change)
#     iteration   19: trace = 0.7770444360997389 (4.26418e-05% change)
#     iteration   20: trace = 0.7770443481573955 (1.13175e-05% change)
#     iteration   21: trace = 0.7770442803603719 (8.72499e-06% change)
# Finished solving for bands 1 to 4 after 21 iterations.
# zevenfreqs:, 1, 0.5, 0, 0, 0.5, 0.387816, 0.42317, 0.465629, 0.480375
# elapsed time for k point: 2.6441049575805664
# total elapsed time for run: 2.7153849601745605
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 135 x 70.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 8.33333, 0)
#      (0, 0, 4.16667)
# Cell volume = 34.7222
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.12, -0)
#      (0, -0, 0.24)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1.66667,0.416667)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      ellipsoid, center = (0,0,0)
#           size (0.5,0.416667,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometry object bounding box tree:
#      box (-0.5625..0.5625, -4.2284..4.2284, -2.14286..2.14286)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, -4.16667)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, 0)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-0.25..0.25, -0.208333..0.208333, -5e+19..5e+19)
#           shift object by (0, 0, 4.16667)
#           ellipsoid, center = (0,0,0)
#                size (0.5,0.416667,1e+20)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (-1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (0, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
#           bounding box (-5e+19..5e+19, -0.833333..0.833333, -0.208333..0.208333)
#           shift object by (1, 0, 0)
#           block, center = (0,0,0)
#                size (1e+20,1.66667,0.416667)
#                axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: zodd.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.1064751148223877
# solve_kpoint (0.5,0,0):
# zoddfreqs:, k index, k1, k2, k3, kmag/2pi, zodd band 1, zodd band 2, zodd band 3, zodd band 4
# Solving for bands 1 to 4...
#     near maximum in trace
#     iteration    1: trace = 8.042077011969274 (188.344% change)
#     iteration    2: trace = 1.351024998608214 (142.467% change)
#     iteration    3: trace = 1.066732965845506 (23.517% change)
#     iteration    4: trace = 0.9979467414558938 (6.66314% change)
#     iteration    5: trace = 0.9729869806196183 (2.53279% change)
#     iteration    6: trace = 0.9582943370225132 (1.52154% change)
#     iteration    7: trace = 0.950061710794516 (0.862798% change)
#     iteration    8: trace = 0.9456249873132797 (0.468086% change)
#     iteration    9: trace = 0.9426060992316151 (0.319758% change)
#     iteration   10: trace = 0.9410061666314802 (0.169879% change)
#     iteration   11: trace = 0.9401645145575314 (0.0894817% change)
#     iteration   12: trace = 0.9398258677504836 (0.0360264% change)
#     iteration   13: trace = 0.9397206282167536 (0.0111984% change)
#     iteration   14: trace = 0.939684796385146 (0.0038131% change)
#     iteration   15: trace = 0.9396728435934939 (0.00127201% change)
#     iteration   16: trace = 0.9396667868705953 (0.000644559% change)
#     iteration   17: trace = 0.9396630552042526 (0.000397127% change)
#     iteration   18: trace = 0.9396607548239198 (0.000244809% change)
#     iteration   19: trace = 0.9396590834806661 (0.000177867% change)
#     iteration   20: trace = 0.9396575068643294 (0.000167786% change)
#     iteration   21: trace = 0.9396550922277292 (0.00025697% change)
#     large trace change predicted (0.000686657%)
#     iteration   22: trace = 0.9396486269119988 (0.000688054% change)
#     large trace change predicted (0.00174218%)
#     iteration   23: trace = 0.9396322408792444 (0.00174386% change)
#     large trace change predicted (0.00588361%)
#     iteration   24: trace = 0.9395800155165817 (0.00555822% change)
#     iteration   25: trace = 0.9394892841939313 (0.00965705% change)
#     iteration   26: trace = 0.9393936045025647 (0.0101847% change)
#     iteration   27: trace = 0.9393042822443302 (0.00950895% change)
#     iteration   28: trace = 0.9392381643225894 (0.00703928% change)
#     iteration   29: trace = 0.9391864061273623 (0.00551081% change)
#     iteration   30: trace = 0.9391499595875471 (0.00388073% change)
#     iteration   31: trace = 0.9391293735424611 (0.00219201% change)
#     iteration   32: trace = 0.9391184958143156 (0.00115828% change)
#     iteration   33: trace = 0.9391108979224794 (0.000809048% change)
#     iteration   34: trace = 0.9391021702909942 (0.000929355% change)
#     iteration   35: trace = 0.9390909168227992 (0.00119833% change)
#     iteration   36: trace = 0.9390758304420364 (0.0016065% change)
#     iteration   37: trace = 0.9390592145341611 (0.00176941% change)
#     iteration   38: trace = 0.9390422968978765 (0.00180157% change)
#     iteration   39: trace = 0.9390237590736348 (0.00197414% change)
#     iteration   40: trace = 0.9390092611797365 (0.00154394% change)
#     iteration   41: trace = 0.9389979202423162 (0.00120776% change)
#     iteration   42: trace = 0.9389884474721852 (0.00100882% change)
#     iteration   43: trace = 0.9389824500058035 (0.000638718% change)
#     iteration   44: trace = 0.9389784535181375 (0.00042562% change)
#     iteration   45: trace = 0.9389748063601318 (0.000388418% change)
#     iteration   46: trace = 0.9389709194299709 (0.000413956% change)
#     iteration   47: trace = 0.9389654871848591 (0.000578533% change)
#     iteration   48: trace = 0.9389574641976323 (0.000854453% change)
#     iteration   49: trace = 0.9389468662426519 (0.0011287% change)
#     iteration   50: trace = 0.9389362128434088 (0.00113462% change)
#     iteration   51: trace = 0.9389255893607735 (0.00113144% change)
#     iteration   52: trace = 0.9389143103827499 (0.00120127% change)
#     iteration   53: trace = 0.9389055255183101 (0.000935645% change)
#     iteration   54: trace = 0.9388990341797194 (0.000691375% change)
#     iteration   55: trace = 0.9388939295301819 (0.000543686% change)
#     iteration   56: trace = 0.9388902010436839 (0.000397116% change)
#     iteration   57: trace = 0.9388870065728065 (0.00034024% change)
#     iteration   58: trace = 0.9388833632131477 (0.000388052% change)
#     iteration   59: trace = 0.9388783966514039 (0.000528987% change)
#     iteration   60: trace = 0.9388710073361277 (0.00078704% change)
#     iteration   61: trace = 0.9388628141466162 (0.000872668% change)
#     iteration   62: trace = 0.9388550089859389 (0.000831345% change)
#     iteration   63: trace = 0.9388473542832102 (0.000815327% change)
#     iteration   64: trace = 0.9388405315861827 (0.000726713% change)
#     iteration   65: trace = 0.9388354129001 (0.000545215% change)
#     iteration   66: trace = 0.9388318733754455 (0.000377013% change)
#     iteration   67: trace = 0.9388292407029262 (0.00028042% change)
#     iteration   68: trace = 0.9388272486687517 (0.000212183% change)
#     iteration   69: trace = 0.9388254420694024 (0.000192432% change)
#     resetting CG direction...
#     iteration   70: trace = 0.9388247869855072 (6.9777e-05% change)
#     iteration   71: trace = 0.9388240538435921 (7.80915e-05% change)
#     iteration   72: trace = 0.9388234192799071 (6.75914e-05% change)
#     iteration   73: trace = 0.9388226346021545 (8.3581e-05% change)
#     large trace change predicted (0.000169326%)
#     iteration   74: trace = 0.9388210416590381 (0.000169675% change)
#     iteration   75: trace = 0.9388180932786131 (0.000314052% change)
#     iteration   76: trace = 0.93881369607697 (0.000468377% change)
#     iteration   77: trace = 0.9388085669965447 (0.000546338% change)
#     iteration   78: trace = 0.9388045302322063 (0.000429989% change)
#     iteration   79: trace = 0.9388014663895244 (0.000326356% change)
#     iteration   80: trace = 0.9387996510882077 (0.000193364% change)
#     iteration   81: trace = 0.938798895381211 (8.04972e-05% change)
#     iteration   82: trace = 0.9387985601408709 (3.57095e-05% change)
#     iteration   83: trace = 0.9387984445873845 (1.23087e-05% change)
#     iteration   84: trace = 0.9387983355587253 (1.16136e-05% change)
#     iteration   85: trace = 0.9387981257066036 (2.23533e-05% change)
#     iteration   86: trace = 0.9387977265645915 (4.25163e-05% change)
#     large trace change predicted (0.000131777%)
#     iteration   87: trace = 0.9387964775471735 (0.000133044% change)
#     iteration   88: trace = 0.9387941774420121 (0.000245006% change)
#     iteration   89: trace = 0.9387922504718644 (0.00020526% change)
#     iteration   90: trace = 0.9387910703205834 (0.00012571% change)
#     iteration   91: trace = 0.9387904755142704 (6.33588e-05% change)
#     iteration   92: trace = 0.9387901966865353 (2.97007e-05% change)
#     iteration   93: trace = 0.9387901064532649 (9.61165e-06% change)
# Finished solving for bands 1 to 4 after 93 iterations.
# zoddfreqs:, 1, 0.5, 0, 0, 0.5, 0.461598, 0.465759, 0.50412, 0.504628
# elapsed time for k point: 10.953449010848999
# total elapsed time for run: 11.06000280380249
# done

# %% [markdown]
# ### 8.2 — Plot a 2-D colour map
#
# The colour map uses a diverging RdBu palette centred on zero, so **white = matching the target frequency**.

# %%
fig, ax = sim.plot_multisweep(
    band_idx=0,
    polarization='zeven',  # 'zeven' (TE-like) or 'zodd' (TM-like)
    units='THz',
    freq0_Hz=f_target,     # subtracts target → shows detuning
    title='TE band 0 detuning from 193.5 THz',
)

# %% [markdown]
# ### 8.3 — Access raw multisweep data

# %%
md_data = sim.multisweep_data

print("Parameter names:", md_data['param_names'])
print("Grid shape:     ", md_data['grid_shape'])
print("TE freqs shape: ", md_data['zeven_freqs'].shape)  # (*grid_shape, 1, num_bands)

# Access individual parameter arrays
lx_vals = md_data['param_grids']['Lx']
p1_vals = md_data['param_grids']['p1']
print("Lx values (µm):", lx_vals)
print("p1 values (µm):", p1_vals)
# Out:
# Parameter names: ['Lx', 'p1']
# Grid shape:      (6, 6)
# TE freqs shape:  (6, 6, 1, 4)
# Lx values (µm): [0.4  0.44 0.48 0.52 0.56 0.6 ]
# p1 values (µm): [0.15 0.18 0.21 0.24 0.27 0.3 ]

# %% [markdown]
# ## 9 — Saving and Loading Results
#
# Results are saved as a `.npz` file (arrays) plus a `_meta.json` file (parameters and gaps).

# %% [markdown]
# ### 9.1 — Save

# %%
sim.save(directory='results', name='silicon_nanobeam_circular')

# Creates:
#   results/silicon_nanobeam_circular.npz
#   results/silicon_nanobeam_circular_meta.json

# %% [markdown]
# ### 9.2 — Load into a new object

# %%
sim2 = BandStructureSim(
    Lx=0.350, Ly=0.500, thickness=0.220,
    geometry="circular", hole_params=[0.200],
    material_index=3.48, num_bands=6, resolution=32,
)

sim2.load(directory='results', name='silicon_nanobeam_circular')

# Plot without re-running the simulation
fig, ax = sim2.plot_bands(units='THz')

# %% [markdown]
# ## 11 — Tips and Best Practices
#
# **Resolution** — Start with `resolution=16` for quick exploration. Increase to 32 or 64
# for publication-quality results. Computation time scales roughly as resolution³.
#
# **Supercell padding** — The defaults `factor_y=5` and `factor_z=10` work well for most
# nanobeam geometries. If you see spurious flat bands near the light line, increase these.
#
# **Number of bands** — Use `num_bands=6–8` for typical nanobeam studies. Higher-order bands
# can mix with the radiation continuum and become unreliable.
#
# **Sweep strategy** — Start with a coarse 1-D sweep (`run_sweep`) to identify the
# interesting parameter range, then zoom in with `run_multisweep` for fine-tuning.
#
# **Normalised vs. physical units** — Normalised units (c/a) are convenient for comparing
# structures with different lattice constants. Switch to THz when targeting a specific
# optical frequency.
